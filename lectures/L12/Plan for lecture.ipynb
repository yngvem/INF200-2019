# %% [markdown]
# # Lecture 12: Interacting with files
#
# In this lecture, we will learn how to interact with the internet and files on your local machine
#
# ## Local files
# We start by interacting with files on your computer. First, we create a file "text_file.txt" and store the string `Hello world!` in it.

# %%
with open('text_file.txt', 'w') as f:
    f.write('Hello world!')

# %% [markdown]
# Now, we can open the file again and read the message

# %%
with open('text_file.txt', 'r') as f:
    print(f.read())
# Out:
# Hello world!

# %% [markdown]
# Next, we want to add a new line, saying hello back

# %%
with open('text_file.txt', 'w') as f:
    f.write('Hello back :)')

# %% [markdown]
# Let us now see if we successfully managed to add two lines to the file

# %%
with open('text_file.txt', 'r') as f:
    print(f.read())
# Out:
# Hello back :)

# %% [markdown]
# Wait, why is there only one line here?
#
# When we open a file in write mode we delete everything in it. Let us see that in action!

# %%
with open('text_file.txt', 'w') as f:
    pass

# %%
with open('text_file.txt', 'r') as f:
    print(f.read())

# %% [markdown]
# So how can we then modify a file!? To do that, we need to open it in *append* mode:

# %%
with open('text_file.txt', 'w') as f:
    f.write('Hello world!')

# %%
with open('text_file.txt', 'a') as f:
    f.write('Hello back :)')

# %%
with open('text_file.txt', 'r') as f:
    print(f.read())
# Out:
# Hello world!Hello back :)

# %% [markdown]
# Now, we at least have the correct text, but we are forgetting a line-break. It is good practice to end all text files with a linebreak!

# %%
with open('text_file.txt', 'w') as f:
    f.write('Hello world!\n')

with open('text_file.txt', 'a') as f:
    f.write('Hello back :)\n')

with open('text_file.txt', 'r') as f:
    print(f.read())
# Out:
# Hello world!
# Hello back :)

# %% [markdown]
# Now we see that we have the file as we want it. Let us think about what the code did.
#
# First, the file is opened in write-mode, then all its contents are deleted and a new file is created. Then, we open it again, but this time in append-mode so that the previous file-content is not deleted. Finally, we open it in read-mode and print the contents.
#
# There is another thing I want you to take notice of. Namely that the file we create is a text-file. It stores plaintext, and as you may remember from the second lecture, plaintext is encoded using UTF-8 (unicode). That is, we have a table with number-letter paris that is used to figure out what text the file contains.
#
# However, text-files are not well suited for data-storage. Consider, for example, if we want to store a 10-digit number in a text file. Then, to load the number, we first need to parse each of the 10 digits and then convert it into an integer. Let us see an example.

# %%
with open('number_file.txt', 'w') as f:
    f.write('1002010100')

with open('number_file.txt') as f:  # Read mode is default
    digit = int(f.read())

# %% [markdown]
# ### Downsides with text-files for data storage:
# Here, we store the digit using 10 bytes instead of the 8 bytes we usually spend to store an integer. This is suboptimal both with respect to space and parse-time. Moreover, if we store tabular data and we want to extract a single row, then we need to read all rows before the one we are interested, since each line may take a different amount of space. By binary data, we can ensure that each row takes the same amount of disk-space, which makes it easier to read from the middle of  the file.

# %% [markdown]
# ### Downsides with binary-files for data storage
# However, there are also downsides with binary files. Firstly, it is not clear solely from the file how it should be read. We need some metadata as well. In Windows, this is the file-extension. For binary files, therefore need special programs or libraries to read and write them. Figuring out the contents of a binary file is therfore much more difficult (we cannot only open it in notepad and view its contents).
#
# In Python, we have the pickle library, which can store arbitrary Python files to disk

# %%
import pickle

with open('binary_file.pickle', 'wb') as f:
    pickle.dump(1002010100, f)

with open('binary_file.pickle', 'rb') as f:
    number = pickle.load(f)

# %%
number
# Out:
# 1002010100

# %% [markdown]
# This is a neat way to store Python files. Be aware, however, since arbitrary code can be stored in pickle files -- also viruses! So don't open pickle files from sources you don't trust.

# %%
with open('binary_file.pickle', 'rb') as f:
    print(f.read())
# Out:
# b'\x80\x03J\xf4u\xb9;.'

# %% [markdown]
# ## Storing data on disk -- serialising object
# Often, we wish to save the state of our program to disk to view it later. There are two ways to do this, either as binary files (for example with pickle), or with a text-serialisation language, such as JSON.
#
# JSON, or JavaScript Object Notation is one of the most popular ways to store data on disk. With JSON files, we store the data as a dictionary whose keys are numbers or strings and values are numbers, strings, lists and more dictionaries (with the same options for keys and values).
#
# JSON is very common, and it is therefore often a good idea to implement a way to store you data as JSON and load your data from a JSON file.

# %%
import json

class Polygon:
    def __init__(self, points):
        self.points = points
    
    def to_json(self):
        return json.dumps(self.points)
    
    def load_json(self, json_string):
        self.points = json.loads(json_string)

# %%
polygon = Polygon([1, 2, 3])

with open('polygon.json', 'w') as f:
    f.write(polygon.to_json())

# %%
new_polygon = Polygon([])

with open('polygon.json', 'r') as f:
    new_polygon.load_json(f.read())

# %%
new_polygon.points
# Out:
# [1, 2, 3]

# %% [markdown]
# This works well. Now, let us take it one step further... Let us use class methods

# %%
import json

class Polygon:
    def __init__(self, points):
        self.points = points
    
    def to_json(self):
        return json.dumps(self.points)
    
    @classmethod
    def load_json(cls, json_string):
        return cls(json.loads(json_string))  # cls becomes Polygon

# %%
with open('polygon.json', 'r') as f:
    new_polygon = Polygon.load_json(f.read())

# %%
new_polygon.points
# Out:
# [1, 2, 3]

# %% [markdown]
# What happened here?
#
# A class method is similar to a normal method, but instead of being used on the instances of the classes, they are used on the class themselves. For instance-methods, we use `self` to represent the instance, in our case, a special case of a polygon. Similarly, for class-methods, we use `cls` to represent the class itself, the input is the class Polygon itself, not a specific instance of it.
#
# For another explanation, see here: https://stackoverflow.com/questions/12179271/meaning-of-classmethod-and-staticmethod-for-beginner

# %% [markdown]
# ## Interacting with web pages
# ### Requests and responses
#
# Have you ever wondered what happens when you connect to a webpage? Well, first you say that you wish to visit a specific webpage, for example, http://nmbu.no. Then, you create a data-structure on your computer called a package. This package has an adress and some information about what you want to do. Then, you send this package to your router, which sends it to your internet service provider, which finds out where to send it next. Then, once the package reaches the server for http://nmbu.no, it is read and http://nmbu.no creates a response package (or more realistically, many response packages, but we'll pretend that all info is sent in one) that it adressess to you. This package is then sent to the server's ISP, which figures out how to get it to you.
#
# I want you to think of each package as a tiny text field which contains four fields. A destination adress (http://nmbu.no), a return adress (your personal IP adress), what you wish to do and the contents of the package. We call these packages for requests, and there are two kinds of requests, GET requests and PUT requests.
#
# A GET-request is you simply saing that you want some information from the server. An example of a GET-request is: "I want to see your frontpage". A PUT-request is the reverse, you wish to give the server some information. An example of a PUT-request is: "I want to log in, here is my username and password".
#
# In this lecture, we will only consider GET-requests.
#
# To send web-requests in Python, we should use the requests library. This library is not a builtin, but it has become the de-facto standard for web-requests with Python.

# %%
import requests

# %% [markdown]
# Let us start with a simple example

# %%
request = requests.get('http://nmbu.no')

# %%
request
# Out:
# <Response [200]>

# %% [markdown]
# Here we see the response-code, 200 means success! Likewise, 404 means not found.

# %%
requests.get('http://nmbu.no/python_is_cool')
# Out:
# <Response [404]>

# %% [markdown]
# There are a whole list of response-codes, you can read about them here: https://realpython.com/python-requests/
#
# Now, back to the first, successful, request.

# %%
request.content
# Out:
# b'<!DOCTYPE html>\n<html lang="nb" dir="ltr">\n  <head>\n    <!-- META FOR IOS & HANDHELD -->\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/>\n    <meta name="HandheldFriendly" content="true" />\n    <meta name="apple-touch-fullscreen" content="YES" />\n    <meta name="msvalidate.01" content="B2B560DCA480DA106B5ED009F4B70148" />\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="shortcut icon" href="https://www.nmbu.no/sites/default/files/favicon_0.ico" type="image/vnd.microsoft.icon" />\n<meta name="generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="canonical" href="https://www.nmbu.no/" />\n<link rel="shortlink" href="https://www.nmbu.no/" />\n<meta property="og:title" content="Forsiden" />\n<meta property="og:updated_time" content="2019-10-11T12:33:36+02:00" />\n<meta name="twitter:title" content="Forsiden" />\n<meta property="article:published_time" content="2019-06-05T13:04:00+02:00" />\n<meta property="article:modified_time" content="2019-10-11T12:33:36+02:00" />\n    <title>Forsiden | Norges milj\xc3\xb8- og biovitenskapelige universitet</title>\n    <link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_-TNq6F6EH1K3WcBMUMQP90OkyCq0Lyv1YnyoEj3kxiU.css" media="screen" />\n<style type="text/css" media="print">\n<!--/*--><![CDATA[/*><!--*/\n#sb-container{position:relative;}#sb-overlay{display:none;}#sb-wrapper{position:relative;top:0;left:0;}#sb-loading{display:none;}\n\n/*]]>*/-->\n</style>\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_8tqKmPOYGXKthhbf9SxssDb4yjnct-L2EWyfcFVUrwQ.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_g1s4LTBAwrA9P_ZKMqGY1wKVPjCkHTitmcKfs7f_9_Q.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_tjH_Hm8svUsSj_qnA6ObBmw8XdtZ0vYYp4AZ1diXIxI.css" media="all" />\n    <script type="text/javascript" src="https://www.nmbu.no/sites/all/libraries/modernizr/modernizr.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/jquery_update/replace/jquery/1.7/jquery.min.js?v=1.7.2"></script>\n<script type="text/javascript" src="https://www.nmbu.no/misc/jquery-extend-3.4.0.js?v=1.7.2"></script>\n<script type="text/javascript" src="https://www.nmbu.no/misc/jquery.once.js?v=1.2"></script>\n<script type="text/javascript" src="https://www.nmbu.no/misc/drupal.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/libraries/shadowbox/shadowbox.js?v=3.0.3"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/shadowbox/shadowbox_auto.js?v=3.0.3"></script>\n<script type="text/javascript">\n<!--//--><![CDATA[//><!--\nDrupal.settings.ais = [{"name":"threshold-480","size":"480"},{"name":"threshold-768","size":"768"},{"name":"threshold-992","size":"992"},{"name":"threshold-1382","size":"1382"}];\nDrupal.settings.ais_method = "width";\n//--><!]]>\n</script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/ajax_links_api/ajax_links_api.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/views_slideshow_xtra/views_slideshow_xtra_overlay/js/views_slideshow_xtra_overlay.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/ctools/js/jump-menu.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/toc_filter/toc_filter.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/ais/assets/js/ais.js?q194k1"></script>\n<script type= ...

# %% [markdown]
# Here, we see the content of the request. It is a byte-string (remember from lecture 2), so we should convert it to a normal string.

# %%
content = request.content.decode()

# %%
content
# Out:
# '<!DOCTYPE html>\n<html lang="nb" dir="ltr">\n  <head>\n    <!-- META FOR IOS & HANDHELD -->\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/>\n    <meta name="HandheldFriendly" content="true" />\n    <meta name="apple-touch-fullscreen" content="YES" />\n    <meta name="msvalidate.01" content="B2B560DCA480DA106B5ED009F4B70148" />\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="shortcut icon" href="https://www.nmbu.no/sites/default/files/favicon_0.ico" type="image/vnd.microsoft.icon" />\n<meta name="generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="canonical" href="https://www.nmbu.no/" />\n<link rel="shortlink" href="https://www.nmbu.no/" />\n<meta property="og:title" content="Forsiden" />\n<meta property="og:updated_time" content="2019-10-11T12:33:36+02:00" />\n<meta name="twitter:title" content="Forsiden" />\n<meta property="article:published_time" content="2019-06-05T13:04:00+02:00" />\n<meta property="article:modified_time" content="2019-10-11T12:33:36+02:00" />\n    <title>Forsiden | Norges miljø- og biovitenskapelige universitet</title>\n    <link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_-TNq6F6EH1K3WcBMUMQP90OkyCq0Lyv1YnyoEj3kxiU.css" media="screen" />\n<style type="text/css" media="print">\n<!--/*--><![CDATA[/*><!--*/\n#sb-container{position:relative;}#sb-overlay{display:none;}#sb-wrapper{position:relative;top:0;left:0;}#sb-loading{display:none;}\n\n/*]]>*/-->\n</style>\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_8tqKmPOYGXKthhbf9SxssDb4yjnct-L2EWyfcFVUrwQ.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_g1s4LTBAwrA9P_ZKMqGY1wKVPjCkHTitmcKfs7f_9_Q.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://www.nmbu.no/sites/default/files/css/css_tjH_Hm8svUsSj_qnA6ObBmw8XdtZ0vYYp4AZ1diXIxI.css" media="all" />\n    <script type="text/javascript" src="https://www.nmbu.no/sites/all/libraries/modernizr/modernizr.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/jquery_update/replace/jquery/1.7/jquery.min.js?v=1.7.2"></script>\n<script type="text/javascript" src="https://www.nmbu.no/misc/jquery-extend-3.4.0.js?v=1.7.2"></script>\n<script type="text/javascript" src="https://www.nmbu.no/misc/jquery.once.js?v=1.2"></script>\n<script type="text/javascript" src="https://www.nmbu.no/misc/drupal.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/libraries/shadowbox/shadowbox.js?v=3.0.3"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/shadowbox/shadowbox_auto.js?v=3.0.3"></script>\n<script type="text/javascript">\n<!--//--><![CDATA[//><!--\nDrupal.settings.ais = [{"name":"threshold-480","size":"480"},{"name":"threshold-768","size":"768"},{"name":"threshold-992","size":"992"},{"name":"threshold-1382","size":"1382"}];\nDrupal.settings.ais_method = "width";\n//--><!]]>\n</script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/ajax_links_api/ajax_links_api.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/views_slideshow_xtra/views_slideshow_xtra_overlay/js/views_slideshow_xtra_overlay.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/ctools/js/jump-menu.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/toc_filter/toc_filter.js?q194k1"></script>\n<script type="text/javascript" src="https://www.nmbu.no/sites/all/modules/contrib/ais/assets/js/ais.js?q194k1"></script>\n<script type="text/ja ...

# %% [markdown]
# ## Enough of a demo, let us see it in action.
#
# A good way to get information from the internet is through public data APIs. For example, Oslo Bysykkel (Oslo city bikes) share anonymous travel information from their webpage https://oslobysykkel.no/apne-data

# %%
headers = {'Client-Identifier': 'Programming class at NMBU'}

bike_data = requests.get(
    'https://gbfs.urbansharing.com/oslobysykkel.no/gbfs.json',
    headers=headers
)

# %%
bike_data.content.decode()
# Out:
# '{"last_updated": 1574685720, "ttl": 10, "data": {"nb": {"feeds": [{"name": "system_information", "url": "http://gbfs.urbansharing.com/oslobysykkel.no/system_information.json"}, {"name": "station_information", "url": "http://gbfs.urbansharing.com/oslobysykkel.no/station_information.json"}, {"name": "station_status", "url": "http://gbfs.urbansharing.com/oslobysykkel.no/station_status.json"}]}}}\n'

# %% [markdown]
# Let us see some cooler examples

# %%
status_endpoint = 'https://gbfs.urbansharing.com/oslobysykkel.no/station_status.json'

station_information_text = requests.get(
    status_endpoint,
    headers=headers
).content.decode()

# %%
station_information_text
# Out:
# '{"last_updated": 1574685724, "ttl": 10, "data": {"stations": [{"station_id": "1101", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 2, "num_docks_available": 20}, {"station_id": "1023", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 10, "num_docks_available": 2}, {"station_id": "1009", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 10}, {"station_id": "970", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 23}, {"station_id": "787", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 8, "num_docks_available": 0}, {"station_id": "627", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 16, "num_docks_available": 14}, {"station_id": "623", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 17, "num_docks_available": 1}, {"station_id": "624", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 20}, {"station_id": "626", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 2, "num_docks_available": 20}, {"station_id": "614", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 24}, {"station_id": "616", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 13, "num_docks_available": 0}, {"station_id": "618", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 41}, {"station_id": "621", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 27}, {"station_id": "622", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 28}, {"station_id": "613", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 1, "num_docks_available": 25}, {"station_id": "620", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 38}, {"station_id": "596", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 18}, {"station_id": "617", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 21}, {"station_id": "609", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 23, "num_docks_available": 4}, {"station_id": "607", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 1, "num_docks_available": 26}, {"station_id": "603", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 3, "num_docks_available": 15}, {"station_id": "590", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 40}, {"station_id": "610", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 5, "num_docks_available": 14}, {"station_id": "608", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported": 1574685724, "num_bikes_available": 0, "num_docks_available": 20}, {"station_id": "593", "is_installed": 1, "is_renting": 1, "is_returning": 1, "last_reported":  ...

# %% [markdown]
# Does this data-format look familiar? It is JSON!

# %%
station_status = json.loads(station_information_text)
station_status
# Out:
# {'last_updated': 1574685724,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '1101',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 20},
#    {'station_id': '1023',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 10,
#     'num_docks_available': 2},
#    {'station_id': '1009',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '970',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 23},
#    {'station_id': '787',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 0},
#    {'station_id': '627',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 16,
#     'num_docks_available': 14},
#    {'station_id': '623',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 1},
#    {'station_id': '624',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '626',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 20},
#    {'station_id': '614',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '616',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 13,
#     'num_docks_available': 0},
#    {'station_id': '618',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 41},
#    {'station_id': '621',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 27},
#    {'station_id': '622',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 28},
#    {'station_id': '613',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 25},
#    {'station_id': '620',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 38},
#    {'station_id': '596',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '617',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '609',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 23,
#     'num_docks_available': 4},
#    {'station_id': '607',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 26},
#    {'station_id': '603',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 15},
#    {'station_id': '590',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 40},
#    {'station_id': '610',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 14},
#    {'station_id': '608',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '593',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 20},
#    {'station_id': '530',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 8},
#    {'station_id': '463',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 18},
#    {'station_id': '475',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 21},
#    {'station_id': '494',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 32},
#    {'station_id': '439',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 24},
#    {'station_id': '600',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 22},
#    {'station_id': '440',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '612',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 13},
#    {'station_id': '491',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 11,
#     'num_docks_available': 6},
#    {'station_id': '492',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 3},
#    {'station_id': '493',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 27},
#    {'station_id': '410',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 26},
#    {'station_id': '605',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '388',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 9},
#    {'station_id': '591',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 16},
#    {'station_id': '592',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '585',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 15},
#    {'station_id': '565',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 17},
#    {'station_id': '571',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 0},
#    {'station_id': '568',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 11},
#    {'station_id': '588',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 17},
#    {'station_id': '569',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '577',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 13,
#     'num_docks_available': 17},
#    {'station_id': '606',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '564',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 28},
#    {'station_id': '570',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 13},
#    {'station_id': '572',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 28,
#     'num_docks_available': 12},
#    {'station_id': '587',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '586',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 19},
#    {'station_id': '576',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 3},
#    {'station_id': '566',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 4},
#    {'station_id': '602',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '575',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '567',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 36},
#    {'station_id': '582',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 12},
#    {'station_id': '595',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 23},
#    {'station_id': '557',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 13},
#    {'station_id': '542',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '563',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 13},
#    {'station_id': '558',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 13,
#     'num_docks_available': 2},
#    {'station_id': '552',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 12},
#    {'station_id': '555',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 14},
#    {'station_id': '573',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 0},
#    {'station_id': '561',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '615',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 18,
#     'num_docks_available': 1},
#    {'station_id': '543',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 9},
#    {'station_id': '554',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 15},
#    {'station_id': '574',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 4,
#     'num_docks_available': 0},
#    {'station_id': '560',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 5},
#    {'station_id': '548',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '559',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 3},
#    {'station_id': '545',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 26,
#     'num_docks_available': 13},
#    {'station_id': '550',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 8},
#    {'station_id': '541',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 2},
#    {'station_id': '527',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 2},
#    {'station_id': '529',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 19},
#    {'station_id': '553',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 23,
#     'num_docks_available': 0},
#    {'station_id': '549',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 12},
#    {'station_id': '526',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 2},
#    {'station_id': '537',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 3},
#    {'station_id': '547',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 12,
#     'num_docks_available': 18},
#    {'station_id': '528',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 14,
#     'num_docks_available': 0},
#    {'station_id': '601',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 12},
#    {'station_id': '533',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 10},
#    {'station_id': '535',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '524',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 20},
#    {'station_id': '519',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 21},
#    {'station_id': '534',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 17},
#    {'station_id': '521',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 8},
#    {'station_id': '518',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '556',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '525',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 9},
#    {'station_id': '517',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 16},
#    {'station_id': '523',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 27},
#    {'station_id': '522',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 2},
#    {'station_id': '594',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 13},
#    {'station_id': '532',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 18},
#    {'station_id': '509',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 1},
#    {'station_id': '531',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 11},
#    {'station_id': '536',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 14},
#    {'station_id': '562',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 27},
#    {'station_id': '511',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 19},
#    {'station_id': '505',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 23},
#    {'station_id': '501',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '514',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '500',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 17},
#    {'station_id': '503',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 25},
#    {'station_id': '513',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '498',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 16},
#    {'station_id': '507',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 10},
#    {'station_id': '512',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 24},
#    {'station_id': '502',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 30},
#    {'station_id': '619',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 41},
#    {'station_id': '474',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 41},
#    {'station_id': '477',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 19},
#    {'station_id': '580',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 45},
#    {'station_id': '496',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 45},
#    {'station_id': '482',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 15},
#    {'station_id': '407',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '409',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 25},
#    {'station_id': '451',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 19},
#    {'station_id': '385',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 15},
#    {'station_id': '402',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '516',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 5},
#    {'station_id': '625',
#     'is_installed': 0,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 42},
#    {'station_id': '429',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 11,
#     'num_docks_available': 10},
#    {'station_id': '380',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '583',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '398',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 12},
#    {'station_id': '381',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 1},
#    {'station_id': '464',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 33},
#    {'station_id': '442',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 16},
#    {'station_id': '483',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 14,
#     'num_docks_available': 1},
#    {'station_id': '458',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 10,
#     'num_docks_available': 5},
#    {'station_id': '499',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 19},
#    {'station_id': '472',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '506',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 24},
#    {'station_id': '465',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 14},
#    {'station_id': '611',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 14,
#     'num_docks_available': 25},
#    {'station_id': '404',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 20},
#    {'station_id': '579',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '589',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 48},
#    {'station_id': '434',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '462',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '578',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '415',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 3},
#    {'station_id': '423',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 14},
#    {'station_id': '412',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 4},
#    {'station_id': '387',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 1},
#    {'station_id': '405',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '441',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 7},
#    {'station_id': '443',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 18,
#     'num_docks_available': 26},
#    {'station_id': '454',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '436',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '394',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '497',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 10,
#     'num_docks_available': 17},
#    {'station_id': '581',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 23},
#    {'station_id': '461',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 20},
#    {'station_id': '599',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 23,
#     'num_docks_available': 24},
#    {'station_id': '400',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 22},
#    {'station_id': '438',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 25,
#     'num_docks_available': 15},
#    {'station_id': '459',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '433',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 17},
#    {'station_id': '399',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 15},
#    {'station_id': '489',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '742',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 22},
#    {'station_id': '551',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 32},
#    {'station_id': '406',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '488',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 4},
#    {'station_id': '540',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 36},
#    {'station_id': '431',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 17},
#    {'station_id': '393',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '420',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '397',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 40},
#    {'station_id': '449',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 5},
#    {'station_id': '484',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 18},
#    {'station_id': '479',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 22,
#     'num_docks_available': 4},
#    {'station_id': '403',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '435',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 28},
#    {'station_id': '426',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '450',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 11},
#    {'station_id': '456',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 52},
#    {'station_id': '468',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '453',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 26},
#    {'station_id': '466',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '469',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 30},
#    {'station_id': '416',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '391',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 17},
#    {'station_id': '389',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '470',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 11},
#    {'station_id': '384',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 17},
#    {'station_id': '425',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 5},
#    {'station_id': '411',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 22},
#    {'station_id': '598',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 18,
#     'num_docks_available': 15},
#    {'station_id': '447',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '408',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '737',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 17},
#    {'station_id': '432',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '401',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 2},
#    {'station_id': '452',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 25},
#    {'station_id': '392',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 21,
#     'num_docks_available': 26},
#    {'station_id': '481',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 25,
#     'num_docks_available': 12},
#    {'station_id': '495',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 19,
#     'num_docks_available': 19},
#    {'station_id': '478',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 11,
#     'num_docks_available': 0},
#    {'station_id': '448',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 6},
#    {'station_id': '414',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 1},
#    {'station_id': '476',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 18},
#    {'station_id': '445',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 11},
#    {'station_id': '748',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 27},
#    {'station_id': '473',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 6},
#    {'station_id': '383',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 27},
#    {'station_id': '480',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 14},
#    {'station_id': '421',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '746',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 9},
#    {'station_id': '386',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '378',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '417',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '427',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '395',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '418',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 11},
#    {'station_id': '413',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '486',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 27},
#    {'station_id': '471',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 9},
#    {'station_id': '597',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 10},
#    {'station_id': '422',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '739',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 14},
#    {'station_id': '382',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 7},
#    {'station_id': '396',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 16,
#     'num_docks_available': 4},
#    {'station_id': '735',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '437',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 5},
#    {'station_id': '446',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 4,
#     'num_docks_available': 20},
#    {'station_id': '424',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 6},
#    {'station_id': '455',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '457',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '377',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '738',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '460',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 26},
#    {'station_id': '734',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 10},
#    {'station_id': '744',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 4,
#     'num_docks_available': 4},
#    {'station_id': '485',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 19}]}}

# %% [markdown]
# Ok, this code is somewhat cumbersome to work with. Let us therefore create a function that does everything above

# %%
def request_json(adress, headers):
    request = requests.get(adress, headers=headers)
    return json.loads(request.content.decode())

station_status = request_json(status_endpoint, headers)

# %%
station_status
# Out:
# {'last_updated': 1574685724,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '1101',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 20},
#    {'station_id': '1023',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 10,
#     'num_docks_available': 2},
#    {'station_id': '1009',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '970',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 23},
#    {'station_id': '787',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 0},
#    {'station_id': '627',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 16,
#     'num_docks_available': 14},
#    {'station_id': '623',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 1},
#    {'station_id': '624',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '626',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 20},
#    {'station_id': '614',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '616',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 13,
#     'num_docks_available': 0},
#    {'station_id': '618',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 41},
#    {'station_id': '621',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 27},
#    {'station_id': '622',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 28},
#    {'station_id': '613',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 25},
#    {'station_id': '620',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 38},
#    {'station_id': '596',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '617',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '609',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 23,
#     'num_docks_available': 4},
#    {'station_id': '607',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 26},
#    {'station_id': '603',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 15},
#    {'station_id': '590',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 40},
#    {'station_id': '610',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 14},
#    {'station_id': '608',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '593',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 20},
#    {'station_id': '530',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 8},
#    {'station_id': '463',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 18},
#    {'station_id': '475',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 21},
#    {'station_id': '494',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 32},
#    {'station_id': '439',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 24},
#    {'station_id': '600',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 22},
#    {'station_id': '440',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '612',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 13},
#    {'station_id': '491',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 11,
#     'num_docks_available': 6},
#    {'station_id': '492',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 3},
#    {'station_id': '493',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 27},
#    {'station_id': '410',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 26},
#    {'station_id': '605',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '388',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 9},
#    {'station_id': '591',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 16},
#    {'station_id': '592',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '585',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 15},
#    {'station_id': '565',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 17},
#    {'station_id': '571',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 0},
#    {'station_id': '568',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 11},
#    {'station_id': '588',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 17},
#    {'station_id': '569',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '577',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 13,
#     'num_docks_available': 17},
#    {'station_id': '606',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '564',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 28},
#    {'station_id': '570',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 13},
#    {'station_id': '572',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 28,
#     'num_docks_available': 12},
#    {'station_id': '587',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '586',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 19},
#    {'station_id': '576',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 3},
#    {'station_id': '566',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 4},
#    {'station_id': '602',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '575',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '567',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 36},
#    {'station_id': '582',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 12},
#    {'station_id': '595',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 23},
#    {'station_id': '557',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 13},
#    {'station_id': '542',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '563',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 13},
#    {'station_id': '558',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 13,
#     'num_docks_available': 2},
#    {'station_id': '552',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 12},
#    {'station_id': '555',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 14},
#    {'station_id': '573',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 0},
#    {'station_id': '561',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '615',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 18,
#     'num_docks_available': 1},
#    {'station_id': '543',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 9},
#    {'station_id': '554',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 15},
#    {'station_id': '574',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 4,
#     'num_docks_available': 0},
#    {'station_id': '560',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 5},
#    {'station_id': '548',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '559',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 3},
#    {'station_id': '545',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 26,
#     'num_docks_available': 13},
#    {'station_id': '550',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 8},
#    {'station_id': '541',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 2},
#    {'station_id': '527',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 2},
#    {'station_id': '529',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 19},
#    {'station_id': '553',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 23,
#     'num_docks_available': 0},
#    {'station_id': '549',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 12},
#    {'station_id': '526',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 2},
#    {'station_id': '537',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 3},
#    {'station_id': '547',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 12,
#     'num_docks_available': 18},
#    {'station_id': '528',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 14,
#     'num_docks_available': 0},
#    {'station_id': '601',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 12},
#    {'station_id': '533',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 10},
#    {'station_id': '535',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '524',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 20},
#    {'station_id': '519',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 21},
#    {'station_id': '534',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 17},
#    {'station_id': '521',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 8},
#    {'station_id': '518',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '556',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '525',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 9},
#    {'station_id': '517',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 16},
#    {'station_id': '523',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 27},
#    {'station_id': '522',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 2},
#    {'station_id': '594',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 13},
#    {'station_id': '532',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 18},
#    {'station_id': '509',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 1},
#    {'station_id': '531',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 11},
#    {'station_id': '536',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 14},
#    {'station_id': '562',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 27},
#    {'station_id': '511',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 19},
#    {'station_id': '505',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 23},
#    {'station_id': '501',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 18},
#    {'station_id': '514',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '500',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 17},
#    {'station_id': '503',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 25},
#    {'station_id': '513',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '498',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 16},
#    {'station_id': '507',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 10},
#    {'station_id': '512',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 24},
#    {'station_id': '502',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 30},
#    {'station_id': '619',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 41},
#    {'station_id': '474',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 41},
#    {'station_id': '477',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 19},
#    {'station_id': '580',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 45},
#    {'station_id': '496',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 45},
#    {'station_id': '482',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 15},
#    {'station_id': '407',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '409',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 25},
#    {'station_id': '451',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 19},
#    {'station_id': '385',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 15},
#    {'station_id': '402',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '516',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 6,
#     'num_docks_available': 5},
#    {'station_id': '625',
#     'is_installed': 0,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 42},
#    {'station_id': '429',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 11,
#     'num_docks_available': 10},
#    {'station_id': '380',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '583',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '398',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 12},
#    {'station_id': '381',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 1},
#    {'station_id': '464',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 33},
#    {'station_id': '442',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 16},
#    {'station_id': '483',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 14,
#     'num_docks_available': 1},
#    {'station_id': '458',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 10,
#     'num_docks_available': 5},
#    {'station_id': '499',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 19},
#    {'station_id': '472',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '506',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 24},
#    {'station_id': '465',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 14},
#    {'station_id': '611',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 14,
#     'num_docks_available': 25},
#    {'station_id': '404',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 20},
#    {'station_id': '579',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '589',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 48},
#    {'station_id': '434',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '462',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '578',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '415',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 3},
#    {'station_id': '423',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 14},
#    {'station_id': '412',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 4},
#    {'station_id': '387',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 1},
#    {'station_id': '405',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '441',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 7},
#    {'station_id': '443',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 18,
#     'num_docks_available': 26},
#    {'station_id': '454',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '436',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '394',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '497',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 10,
#     'num_docks_available': 17},
#    {'station_id': '581',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 23},
#    {'station_id': '461',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 20},
#    {'station_id': '599',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 23,
#     'num_docks_available': 24},
#    {'station_id': '400',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 22},
#    {'station_id': '438',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 25,
#     'num_docks_available': 15},
#    {'station_id': '459',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '433',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 17},
#    {'station_id': '399',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 15},
#    {'station_id': '489',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '742',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 8,
#     'num_docks_available': 22},
#    {'station_id': '551',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 32},
#    {'station_id': '406',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '488',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 20,
#     'num_docks_available': 4},
#    {'station_id': '540',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 36},
#    {'station_id': '431',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 17},
#    {'station_id': '393',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '420',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 20},
#    {'station_id': '397',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 40},
#    {'station_id': '449',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 5},
#    {'station_id': '484',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 17,
#     'num_docks_available': 18},
#    {'station_id': '479',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 22,
#     'num_docks_available': 4},
#    {'station_id': '403',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '435',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 28},
#    {'station_id': '426',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 21},
#    {'station_id': '450',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 11},
#    {'station_id': '456',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 52},
#    {'station_id': '468',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '453',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 26},
#    {'station_id': '466',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '469',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 30},
#    {'station_id': '416',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '391',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 17},
#    {'station_id': '389',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '470',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 11},
#    {'station_id': '384',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 17},
#    {'station_id': '425',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 5},
#    {'station_id': '411',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 22},
#    {'station_id': '598',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 18,
#     'num_docks_available': 15},
#    {'station_id': '447',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '408',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '737',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 17},
#    {'station_id': '432',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '401',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 2},
#    {'station_id': '452',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 25},
#    {'station_id': '392',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 21,
#     'num_docks_available': 26},
#    {'station_id': '481',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 25,
#     'num_docks_available': 12},
#    {'station_id': '495',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 19,
#     'num_docks_available': 19},
#    {'station_id': '478',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 11,
#     'num_docks_available': 0},
#    {'station_id': '448',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 6},
#    {'station_id': '414',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 1},
#    {'station_id': '476',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 2,
#     'num_docks_available': 18},
#    {'station_id': '445',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 7,
#     'num_docks_available': 11},
#    {'station_id': '748',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 27},
#    {'station_id': '473',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 6},
#    {'station_id': '383',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 27},
#    {'station_id': '480',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 5,
#     'num_docks_available': 14},
#    {'station_id': '421',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 24},
#    {'station_id': '746',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 9},
#    {'station_id': '386',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 15},
#    {'station_id': '378',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '417',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '427',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '395',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 14},
#    {'station_id': '418',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 11},
#    {'station_id': '413',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 16},
#    {'station_id': '486',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 27},
#    {'station_id': '471',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 9},
#    {'station_id': '597',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 3,
#     'num_docks_available': 10},
#    {'station_id': '422',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '739',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 14},
#    {'station_id': '382',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 7},
#    {'station_id': '396',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 16,
#     'num_docks_available': 4},
#    {'station_id': '735',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '437',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 15,
#     'num_docks_available': 5},
#    {'station_id': '446',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 4,
#     'num_docks_available': 20},
#    {'station_id': '424',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 1,
#     'num_docks_available': 6},
#    {'station_id': '455',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 12},
#    {'station_id': '457',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 10},
#    {'station_id': '377',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 29},
#    {'station_id': '738',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 11},
#    {'station_id': '460',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 26},
#    {'station_id': '734',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 9,
#     'num_docks_available': 10},
#    {'station_id': '744',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 4,
#     'num_docks_available': 4},
#    {'station_id': '485',
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1574685724,
#     'num_bikes_available': 0,
#     'num_docks_available': 19}]}}

# %%
station_status['data'].keys()
# Out:
# dict_keys(['stations'])

# %% [markdown]
# Let us now create a station-class that we can use to wrap these station-dictionaries in

# %%
class Station:
    def __init__(
        self,
        station_id,
        is_installed,
        is_renting,
        is_returning,
        last_reported,
        num_bikes_available,
        num_docks_available
    ):
        self.station_id = station_id
        self.is_installed = is_installed
        self.is_renting = is_renting
        self.is_returning = is_returning
        self.last_reported = last_reported
        self.num_bikes_available = num_bikes_available
        self.num_docks_available = num_docks_available

    def __repr__(self):
        return f'<Station {self.station_id}>'
    
    def __str__(self):
        return f"""\
            ID: {self.station_id}
            Installed: {self.is_installed}
            Renting: {self.is_renting}
            Returning: {self.is_returning}
            Last reported: {self.last_reported}
            Number of available bikes: {self.num_bikes_available}
            Number of available docking stations: {self.num_docks_available}"""
    
    
stations = [
    Station(**station_info) for station_info in station_status['data']['stations']
]

# %%
print(str(stations[0]))
# Out:
#             ID: 1101
#             Installed: 1
#             Renting: 1
#             Returning: 1
#             Last reported: 1574685724
#             Number of available bikes: 2
#             Number of available docking stations: 20

# %% [markdown]
# Now, what is this last-reported information? It is a time-stamp with the number of seconds since 1st of January, 1970, also known as time since epoch

# %%
import time

def parse_time(time_since_epoch):
    return time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(time_since_epoch))

# %%
class Station:
    def __init__(
        self,
        station_id,
        is_installed,
        is_renting,
        is_returning,
        last_reported,
        num_bikes_available,
        num_docks_available
    ):
        self.station_id = station_id
        self.is_installed = is_installed
        self.is_renting = is_renting
        self.is_returning = is_returning
        self.last_reported = parse_time(last_reported)
        self.num_bikes_available = num_bikes_available
        self.num_docks_available = num_docks_available

    def __repr__(self):
        return f'<Station {self.station_id}>'
    
    def __str__(self):
        return f"""\
            ID: {self.station_id}
            Installed: {self.is_installed}
            Renting: {self.is_renting}
            Returning: {self.is_returning}
            Last reported: {self.last_reported}
            Number of available bikes: {self.num_bikes_available}
            Number of available docking stations: {self.num_docks_available}"""
    
    
stations = [
    Station(**station_info) for station_info in station_status['data']['stations']
]

# %%
print(stations[0])
# Out:
#             ID: 1101
#             Installed: 1
#             Renting: 1
#             Returning: 1
#             Last reported: 2019-11-25 13:42:04
#             Number of available bikes: 2
#             Number of available docking stations: 20

# %%
print(stations[1])
# Out:
#             ID: 1023
#             Installed: 1
#             Renting: 1
#             Returning: 1
#             Last reported: 2019-11-25 13:42:04
#             Number of available bikes: 10
#             Number of available docking stations: 2

# %% [markdown]
# Next, we want a map between IDs and station names

# %%
station_metadata = request_json('https://gbfs.urbansharing.com/oslobysykkel.no/station_information.json', headers)
station_metadata
# Out:
# {'last_updated': 1574685758,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '1101',
#     'name': 'Stortingstunellen',
#     'address': 'Rådhusgata 34',
#     'lat': 59.91065301806209,
#     'lon': 10.737365277561025,
#     'capacity': 24},
#    {'station_id': '1023',
#     'name': 'Professor Aschehougs plass',
#     'address': 'Professor Aschehougs plass',
#     'lat': 59.9147672,
#     'lon': 10.740971,
#     'capacity': 12},
#    {'station_id': '1009',
#     'name': 'Borgenveien',
#     'address': 'Borgenveien',
#     'lat': 59.942742106473666,
#     'lon': 10.703833031254021,
#     'capacity': 10},
#    {'station_id': '970',
#     'name': 'Enerhaugen',
#     'address': 'ved Sørligata',
#     'lat': 59.91320242563816,
#     'lon': 10.767579386407874,
#     'capacity': 25},
#    {'station_id': '787',
#     'name': 'Kirkegata 15',
#     'address': 'Kirkegata 15, Oslo',
#     'lat': 59.91015615055511,
#     'lon': 10.743456971511705,
#     'capacity': 12},
#    {'station_id': '627',
#     'name': 'Skøyen Stasjon',
#     'address': 'Skøyen Stasjon',
#     'lat': 59.9226729,
#     'lon': 10.6788129,
#     'capacity': 30},
#    {'station_id': '623',
#     'name': '7 Juni Plassen',
#     'address': '7 Juni Plassen',
#     'lat': 59.9150596,
#     'lon': 10.7312715,
#     'capacity': 21},
#    {'station_id': '624',
#     'name': 'Dælenenggata',
#     'address': 'Dælenenggata ved Fagerheimgata',
#     'lat': 59.928716,
#     'lon': 10.7675618,
#     'capacity': 20},
#    {'station_id': '626',
#     'name': 'Drammensveien',
#     'address': 'Drammensveien 119',
#     'lat': 59.9204038,
#     'lon': 10.691147,
#     'capacity': 24},
#    {'station_id': '614',
#     'name': 'Sinsen T-bane',
#     'address': 'Sinsen t-bane',
#     'lat': 59.938808,
#     'lon': 10.780445,
#     'capacity': 24},
#    {'station_id': '616',
#     'name': 'Salt',
#     'address': 'Salt ved Langkaia',
#     'lat': 59.9069066,
#     'lon': 10.7466245,
#     'capacity': 15},
#    {'station_id': '618',
#     'name': 'Bak Niels Treschows hus sør',
#     'address': 'Bak Niels Treschows hus sør',
#     'lat': 59.9424323,
#     'lon': 10.723903,
#     'capacity': 42},
#    {'station_id': '621',
#     'name': 'Torshovdalen øst',
#     'address': 'Torshovdalen øst',
#     'lat': 59.9328069,
#     'lon': 10.7774484,
#     'capacity': 27},
#    {'station_id': '622',
#     'name': 'Pilestredet 63',
#     'address': 'Pilestredet 63',
#     'lat': 59.9238826,
#     'lon': 10.7313627,
#     'capacity': 30},
#    {'station_id': '613',
#     'name': 'Schives gate',
#     'address': 'Schives gate',
#     'lat': 59.9208044,
#     'lon': 10.7140544,
#     'capacity': 27},
#    {'station_id': '620',
#     'name': 'Bislettgata',
#     'address': 'Bislettgata',
#     'lat': 59.9238336,
#     'lon': 10.7346377,
#     'capacity': 40},
#    {'station_id': '596',
#     'name': 'Idioten',
#     'address': 'Idioten',
#     'lat': 59.9310814,
#     'lon': 10.7360029,
#     'capacity': 18},
#    {'station_id': '617',
#     'name': 'Bjerregaardsgate Øst',
#     'address': 'Bjerregaardsgate Øst',
#     'lat': 59.9272161,
#     'lon': 10.7497787,
#     'capacity': 21},
#    {'station_id': '609',
#     'name': 'Fred Olsens gate',
#     'address': 'Fred Olsens gate',
#     'lat': 59.9110506,
#     'lon': 10.7493737,
#     'capacity': 27},
#    {'station_id': '607',
#     'name': 'Marcus Thranes gate',
#     'address': 'Marcus Thranes gate',
#     'lat': 59.9327471,
#     'lon': 10.7585697,
#     'capacity': 30},
#    {'station_id': '603',
#     'name': 'Frogner plass',
#     'address': 'Frogner plass',
#     'lat': 59.9225392,
#     'lon': 10.7045406,
#     'capacity': 18},
#    {'station_id': '590',
#     'name': 'Majorstua skole',
#     'address': 'Majorstua skole',
#     'lat': 59.9294351,
#     'lon': 10.7136816,
#     'capacity': 40},
#    {'station_id': '610',
#     'name': 'Sotahjørnet',
#     'address': 'Sotahjørnet',
#     'lat': 59.9099822,
#     'lon': 10.7914482,
#     'capacity': 20},
#    {'station_id': '608',
#     'name': 'Colletts gate',
#     'address': 'Colletts/Diriks gate',
#     'lat': 59.9307367,
#     'lon': 10.746379,
#     'capacity': 21},
#    {'station_id': '593',
#     'name': 'Bjølsen mølle',
#     'address': 'Bjølsen mølle',
#     'lat': 59.9392,
#     'lon': 10.768774,
#     'capacity': 30},
#    {'station_id': '530',
#     'name': 'Holbergs Plass',
#     'address': 'Holbergs Plass',
#     'lat': 59.9193095,
#     'lon': 10.7343051,
#     'capacity': 10},
#    {'station_id': '463',
#     'name': 'Schous plass trikkestopp',
#     'address': 'Schous plass trikkestopp',
#     'lat': 59.9207284,
#     'lon': 10.7594857,
#     'capacity': 20},
#    {'station_id': '475',
#     'name': 'Hausmanns bru',
#     'address': 'Hausmanns bru',
#     'lat': 59.9146509,
#     'lon': 10.7598719,
#     'capacity': 24},
#    {'station_id': '494',
#     'name': 'Rådhusbrygge 4',
#     'address': 'Rådhusbrygge 4',
#     'lat': 59.9108469,
#     'lon': 10.7303766,
#     'capacity': 40},
#    {'station_id': '439',
#     'name': 'Mølleparken',
#     'address': 'Mølleparken',
#     'lat': 59.9283928,
#     'lon': 10.7559693,
#     'capacity': 25},
#    {'station_id': '600',
#     'name': 'Dyvekes bru',
#     'address': 'Dyvekes bru',
#     'lat': 59.905323,
#     'lon': 10.7689579,
#     'capacity': 24},
#    {'station_id': '440',
#     'name': 'Lakkegata',
#     'address': 'Lakkegata',
#     'lat': 59.9172088,
#     'lon': 10.7622135,
#     'capacity': 18},
#    {'station_id': '612',
#     'name': 'Ensjøveien',
#     'address': 'Ensjøveien',
#     'lat': 59.9167033,
#     'lon': 10.7833627,
#     'capacity': 19},
#    {'station_id': '491',
#     'name': 'Brugata',
#     'address': 'Brugata 17',
#     'lat': 59.91366109486603,
#     'lon': 10.75729364846211,
#     'capacity': 18},
#    {'station_id': '492',
#     'name': 'Goethe Institut',
#     'address': 'Goethe Institut',
#     'lat': 59.9131792,
#     'lon': 10.7607798,
#     'capacity': 12},
#    {'station_id': '493',
#     'name': 'Sofienbergparken nordvest',
#     'address': 'Sofienbergparken nordvest',
#     'lat': 59.9243639,
#     'lon': 10.7615858,
#     'capacity': 30},
#    {'station_id': '410',
#     'name': 'Landstads gate',
#     'address': 'Circle K Kiellands',
#     'lat': 59.929005,
#     'lon': 10.7496755,
#     'capacity': 27},
#    {'station_id': '605',
#     'name': 'Økernveien',
#     'address': 'Økernveien ved bussholdeplass Ensjøveien\nØkernveien ved bussholdeplass Ensjøveien',
#     'lat': 59.9167376,
#     'lon': 10.779916,
#     'capacity': 24},
#    {'station_id': '388',
#     'name': 'Skovveien',
#     'address': 'Skovveien ved Frognerveien',
#     'lat': 59.9163309,
#     'lon': 10.716349,
#     'capacity': 18},
#    {'station_id': '591',
#     'name': 'Grenseveien',
#     'address': 'Grenseveien',
#     'lat': 59.9246227,
#     'lon': 10.7815924,
#     'capacity': 24},
#    {'station_id': '592',
#     'name': 'Badebakken',
#     'address': 'Maridalsveien / Badebakken',
#     'lat': 59.9455883,
#     'lon': 10.7604191,
#     'capacity': 18},
#    {'station_id': '585',
#     'name': 'Nordre gate',
#     'address': 'Nordre gate',
#     'lat': 59.9212171,
#     'lon': 10.7547918,
#     'capacity': 18},
#    {'station_id': '565',
#     'name': 'Mailundveien',
#     'address': 'Mailundveien - Rosenhoffgata',
#     'lat': 59.9309181,
#     'lon': 10.7728203,
#     'capacity': 18},
#    {'station_id': '571',
#     'name': 'Over Rådhusgata',
#     'address': 'Nedre Slottsgate 4',
#     'lat': 59.9101207,
#     'lon': 10.7407129,
#     'capacity': 21},
#    {'station_id': '568',
#     'name': 'Frognerveien',
#     'address': 'Frognerveien 15',
#     'lat': 59.9170851,
#     'lon': 10.7128796,
#     'capacity': 15},
#    {'station_id': '588',
#     'name': 'Meltzers gate',
#     'address': 'Meltzers gate ved Skovveien ',
#     'lat': 59.9180141,
#     'lon': 10.7184345,
#     'capacity': 21},
#    {'station_id': '569',
#     'name': 'Botanisk hage sør-vest',
#     'address': 'Sars gate',
#     'lat': 59.9177943,
#     'lon': 10.7662784,
#     'capacity': 30},
#    {'station_id': '577',
#     'name': 'Arkaden Nord',
#     'address': 'Dronningens gate ved Arkaden II',
#     'lat': 59.9121472,
#     'lon': 10.7480527,
#     'capacity': 30},
#    {'station_id': '606',
#     'name': 'Stockfleths gate',
#     'address': 'Stockfleths gate/ griffenfeldts',
#     'lat': 59.9339754,
#     'lon': 10.7521029,
#     'capacity': 18},
#    {'station_id': '564',
#     'name': 'Oscars gate',
#     'address': 'Oscars gate - Hegdehaugsveien',
#     'lat': 59.9224222,
#     'lon': 10.7272388,
#     'capacity': 30},
#    {'station_id': '570',
#     'name': 'Frøen T-bane',
#     'address': 'Frøen T-bane',
#     'lat': 59.9347352,
#     'lon': 10.7096985,
#     'capacity': 15},
#    {'station_id': '572',
#     'name': 'Skøyen',
#     'address': 'Skøyen (under bro)',
#     'lat': 59.922247,
#     'lon': 10.679738,
#     'capacity': 40},
#    {'station_id': '587',
#     'name': 'Riddervoldplass',
#     'address': 'Riddervoldplass , Camilla Colletts vei',
#     'lat': 59.9191421,
#     'lon': 10.7196414,
#     'capacity': 15},
#    {'station_id': '586',
#     'name': 'Københavngata busstopp',
#     'address': 'Københavngata busstopp',
#     'lat': 59.9294754,
#     'lon': 10.769151,
#     'capacity': 27},
#    {'station_id': '576',
#     'name': 'Dronningens gate',
#     'address': 'Dronningens gate 25',
#     'lat': 59.91138423128484,
#     'lon': 10.747318039414154,
#     'capacity': 18},
#    {'station_id': '566',
#     'name': 'Hoff terrasse holdeplass',
#     'address': 'Hoffsveien - Engebrets vei',
#     'lat': 59.9272941,
#     'lon': 10.6755714,
#     'capacity': 24},
#    {'station_id': '602',
#     'name': 'Jarlsborgveien',
#     'address': 'Jarlsborgveien- Hoffsveien',
#     'lat': 59.9304645,
#     'lon': 10.6757833,
#     'capacity': 18},
#    {'station_id': '575',
#     'name': 'Sognsveien',
#     'address': 'Sognsveien ved Ullevål T-bane',
#     'lat': 59.9474863,
#     'lon': 10.7324195,
#     'capacity': 30},
#    {'station_id': '567',
#     'name': 'Forskningsveien',
#     'address': 'Forskningsveien',
#     'lat': 59.9454775,
#     'lon': 10.7138465,
#     'capacity': 39},
#    {'station_id': '582',
#     'name': 'Stavangergata',
#     'address': 'Stavangergata',
#     'lat': 59.941108,
#     'lon': 10.7506048,
#     'capacity': 30},
#    {'station_id': '595',
#     'name': 'Skarpsnoparken',
#     'address': 'Skarpsnoparken',
#     'lat': 59.914871,
#     'lon': 10.701037,
#     'capacity': 24},
#    {'station_id': '557',
#     'name': 'Akersgata',
#     'address': 'Akersgata - Grensen',
#     'lat': 59.9141971,
#     'lon': 10.7428828,
#     'capacity': 21},
#    {'station_id': '542',
#     'name': 'Grünerhagen Nord',
#     'address': 'Fossveien - Sofienberggata',
#     'lat': 59.9224256,
#     'lon': 10.7554274,
#     'capacity': 20},
#    {'station_id': '563',
#     'name': 'Huitfeldts gate',
#     'address': 'Huitfeldts gate 24',
#     'lat': 59.9126844,
#     'lon': 10.7229003,
#     'capacity': 18},
#    {'station_id': '558',
#     'name': 'Dokkveien',
#     'address': 'Dokkveien',
#     'lat': 59.910974,
#     'lon': 10.7277001,
#     'capacity': 15},
#    {'station_id': '552',
#     'name': 'Trelastgata',
#     'address': 'Bjørvika / Trelastgata',
#     'lat': 59.907967,
#     'lon': 10.762621,
#     'capacity': 18},
#    {'station_id': '555',
#     'name': 'Griffenfeldts gate',
#     'address': 'Griffenfeldts gate - Colletts gate',
#     'lat': 59.9337026,
#     'lon': 10.7519299,
#     'capacity': 15},
#    {'station_id': '573',
#     'name': 'Tordenskiolds gate',
#     'address': 'Tordenskiolds gate - Otto Sverdrups gate',
#     'lat': 59.9117882,
#     'lon': 10.7351647,
#     'capacity': 24},
#    {'station_id': '561',
#     'name': 'Kirkeveien',
#     'address': 'Kirkeveien - Gørbitz gate\n',
#     'lat': 59.9335582,
#     'lon': 10.7264261,
#     'capacity': 24},
#    {'station_id': '615',
#     'name': 'Munkedamsveien',
#     'address': 'Konserthuset/Munkedamsveien',
#     'lat': 59.9135227,
#     'lon': 10.7301061,
#     'capacity': 21},
#    {'station_id': '543',
#     'name': 'Fyrstikktorget',
#     'address': 'Fyrstikktorget',
#     'lat': 59.9138347,
#     'lon': 10.7981175,
#     'capacity': 20},
#    {'station_id': '554',
#     'name': 'Tåsen Senter',
#     'address': 'Tåsen senter\n',
#     'lat': 59.952659,
#     'lon': 10.751165,
#     'capacity': 21},
#    {'station_id': '574',
#     'name': 'Annette Thommessens Plass',
#     'address': 'Annette Thommesens Plass\n',
#     'lat': 59.9107393,
#     'lon': 10.7609998,
#     'capacity': 12},
#    {'station_id': '560',
#     'name': 'Gaustad T-bane',
#     'address': 'Gaustad T-bane',
#     'lat': 59.945955,
#     'lon': 10.710392,
#     'capacity': 9},
#    {'station_id': '548',
#     'name': 'Colbjørnsens gate',
#     'address': 'Colbjørnsens gate',
#     'lat': 59.917293,
#     'lon': 10.716796,
#     'capacity': 18},
#    {'station_id': '559',
#     'name': 'Hoffsveien',
#     'address': 'Hoffsveien',
#     'lat': 59.923898,
#     'lon': 10.6760339,
#     'capacity': 18},
#    {'station_id': '545',
#     'name': 'Arkaden Sør',
#     'address': 'Dronningens gate ved Arkaden\n',
#     'lat': 59.9119691,
#     'lon': 10.7478583,
#     'capacity': 39},
#    {'station_id': '550',
#     'name': 'Thereses gate',
#     'address': "Therese's gate 49\n",
#     'lat': 59.9261462,
#     'lon': 10.7310355,
#     'capacity': 9},
#    {'station_id': '541',
#     'name': 'Langkaia',
#     'address': 'rådhusgata / langkaia',
#     'lat': 59.9080552,
#     'lon': 10.7479977,
#     'capacity': 12},
#    {'station_id': '527',
#     'name': "Biskop Gunnerus' gate",
#     'address': 'Oslo City - Biskop Gunnerus gate\n',
#     'lat': 59.9123341,
#     'lon': 10.752292,
#     'capacity': 12},
#    {'station_id': '529',
#     'name': 'Friggfeltet',
#     'address': 'Slemdalsveien ved Frigg',
#     'lat': 59.9327726,
#     'lon': 10.7114661,
#     'capacity': 21},
#    {'station_id': '553',
#     'name': 'Skråninga',
#     'address': 'Skråninga',
#     'lat': 59.9139786,
#     'lon': 10.7474667,
#     'capacity': 25},
#    {'station_id': '549',
#     'name': 'Linaaes gate',
#     'address': 'Møllergata 3',
#     'lat': 59.913832,
#     'lon': 10.7457018,
#     'capacity': 21},
#    {'station_id': '526',
#     'name': 'Lille Grensen',
#     'address': 'Lille Grensen - Akersgata 43',
#     'lat': 59.9138973,
#     'lon': 10.7423101,
#     'capacity': 15},
#    {'station_id': '537',
#     'name': 'St. Olavs gate',
#     'address': 'St.Olavs gate 21 - Pilestredet',
#     'lat': 59.9179859,
#     'lon': 10.7385805,
#     'capacity': 20},
#    {'station_id': '547',
#     'name': 'Skippergata',
#     'address': 'Skippergata - Karl Johans gate',
#     'lat': 59.9112227,
#     'lon': 10.7481976,
#     'capacity': 30},
#    {'station_id': '528',
#     'name': 'Nedre Slottsgate',
#     'address': 'Nedre Slottsgate 12',
#     'lat': 59.913245,
#     'lon': 10.743669,
#     'capacity': 15},
#    {'station_id': '601',
#     'name': 'Rolf Wickstrøms vei',
#     'address': 'Rolf Wickstrøms vei',
#     'lat': 59.9534114,
#     'lon': 10.7577241,
#     'capacity': 20},
#    {'station_id': '533',
#     'name': 'Sørvest for Slottsparken',
#     'address': 'Henrik Ibsens gate 40',
#     'lat': 59.915262,
#     'lon': 10.7253157,
#     'capacity': 12},
#    {'station_id': '535',
#     'name': 'Uranienborgveien',
#     'address': 'Uranienborgveien - Parkveien',
#     'lat': 59.9200421,
#     'lon': 10.726634,
#     'capacity': 27},
#    {'station_id': '524',
#     'name': 'Volvat',
#     'address': 'Sørkedalsveien ved Skeidar',
#     'lat': 59.9330951,
#     'lon': 10.7040189,
#     'capacity': 21},
#    {'station_id': '519',
#     'name': 'Thomas Heftyes plass',
#     'address': 'Bygdøy alle/Elisenbergveien',
#     'lat': 59.9185405,
#     'lon': 10.7039116,
#     'capacity': 24},
#    {'station_id': '534',
#     'name': 'Filipstadveien',
#     'address': 'Filipstadveien El-bilparkering/busslomme',
#     'lat': 59.9102277,
#     'lon': 10.7208788,
#     'capacity': 39},
#    {'station_id': '521',
#     'name': 'Jess Carlsens gate',
#     'address': 'Jess Carlsens gate',
#     'lat': 59.9186359,
#     'lon': 10.7523939,
#     'capacity': 15},
#    {'station_id': '518',
#     'name': 'Ullevålsveien',
#     'address': 'Ullevålsveien 47 - Schwenssens gate',
#     'lat': 59.9246852,
#     'lon': 10.7395045,
#     'capacity': 18},
#    {'station_id': '556',
#     'name': 'Pilestredet',
#     'address': 'Pilestredet 75',
#     'lat': 59.9262242,
#     'lon': 10.7296246,
#     'capacity': 18},
#    {'station_id': '525',
#     'name': 'Myraløkka Øst',
#     'address': 'Bentsebrugata - Arendalsgata',
#     'lat': 59.937205,
#     'lon': 10.7605813,
#     'capacity': 15},
#    {'station_id': '517',
#     'name': 'Tåsenløkka',
#     'address': 'Uelands gate - Voldsløkka',
#     'lat': 59.9433939,
#     'lon': 10.7482848,
#     'capacity': 18},
#    {'station_id': '523',
#     'name': 'Tøyenbekken',
#     'address': 'Tøyenbekken',
#     'lat': 59.9115945,
#     'lon': 10.7617736,
#     'capacity': 30},
#    {'station_id': '522',
#     'name': 'Mandalls gate',
#     'address': 'Mandalls gate',
#     'lat': 59.9123469,
#     'lon': 10.7638147,
#     'capacity': 10},
#    {'station_id': '594',
#     'name': 'Kampen park Øst',
#     'address': 'Kampen park øst',
#     'lat': 59.915182,
#     'lon': 10.782129,
#     'capacity': 21},
#    {'station_id': '532',
#     'name': 'Brynseng T-bane',
#     'address': 'Brynseng t-bane',
#     'lat': 59.909238,
#     'lon': 10.814199,
#     'capacity': 21},
#    {'station_id': '509',
#     'name': 'Kjeld Stubs gate',
#     'address': 'Kjeld Stubs gate',
#     'lat': 59.912711,
#     'lon': 10.735595,
#     'capacity': 12},
#    {'station_id': '531',
#     'name': 'Monolittveien',
#     'address': 'Smestaddammen (Monolittveien/Hoffsveien)',
#     'lat': 59.935947,
#     'lon': 10.681138,
#     'capacity': 18},
#    {'station_id': '536',
#     'name': 'Diakonhjemmet',
#     'address': 'Diakonhjemmet - Høyskolen',
#     'lat': 59.9363277,
#     'lon': 10.7054333,
#     'capacity': 15},
#    {'station_id': '562',
#     'name': 'Slottsparken Øst',
#     'address': 'St Olavsgate / Kristian IV gate',
#     'lat': 59.917485,
#     'lon': 10.732128,
#     'capacity': 40},
#    {'station_id': '511',
#     'name': 'Henrik Ibsens gate',
#     'address': 'Parkveien / Henrik Ibsens gate',
#     'lat': 59.915088,
#     'lon': 10.7222803,
#     'capacity': 24},
#    {'station_id': '505',
#     'name': 'Marienlystparken',
#     'address': 'Marienlyst / Kirkeveien',
#     'lat': 59.93215,
#     'lon': 10.723478,
#     'capacity': 24},
#    {'station_id': '501',
#     'name': "Krebs' gate",
#     'address': "Krebs' gate / Vogstgate",
#     'lat': 59.935995,
#     'lon': 10.765413,
#     'capacity': 18},
#    {'station_id': '514',
#     'name': 'Sofienberggata',
#     'address': 'Sofienberggata / Trondheimsveien',
#     'lat': 59.9212063,
#     'lon': 10.7699892,
#     'capacity': 12},
#    {'station_id': '500',
#     'name': 'Anker Hostel',
#     'address': 'Storgata 57 Anker Hotell',
#     'lat': 59.9172794,
#     'lon': 10.7581553,
#     'capacity': 27},
#    {'station_id': '503',
#     'name': 'Fagerheimgata',
#     'address': 'Fagerheimgata / Malmøgata',
#     'lat': 59.9274634,
#     'lon': 10.7657433,
#     'capacity': 33},
#    {'station_id': '513',
#     'name': 'Bøkkerveien',
#     'address': 'Hasle Linje / Bøkkerveien ved Cafe Nord',
#     'lat': 59.9273747,
#     'lon': 10.7960147,
#     'capacity': 15},
#    {'station_id': '498',
#     'name': 'HasleLinje',
#     'address': 'Hasle Linje / Karevsvingen ved BYM',
#     'lat': 59.9276408,
#     'lon': 10.7992011,
#     'capacity': 18},
#    {'station_id': '507',
#     'name': 'Jens Bjelkes gate',
#     'address': 'Jens Bjelkes gate / Trondheimsveien',
#     'lat': 59.919179,
#     'lon': 10.764162,
#     'capacity': 15},
#    {'station_id': '512',
#     'name': 'Ensjø T-bane',
#     'address': 'Ensjø t-bane',
#     'lat': 59.9131891,
#     'lon': 10.7897605,
#     'capacity': 30},
#    {'station_id': '502',
#     'name': 'Ullevål sykehus',
#     'address': 'Kirkeveien / Ullevål sykehus',
#     'lat': 59.9360307,
#     'lon': 10.7364516,
#     'capacity': 35},
#    {'station_id': '619',
#     'name': 'Bak Niels Treschows hus nord',
#     'address': 'Bak Niels Treschows nord',
#     'lat': 59.942780248542554,
#     'lon': 10.722993731144015,
#     'capacity': 42},
#    {'station_id': '474',
#     'name': 'Blindern studentparkering',
#     'address': 'Blindern studentparkering',
#     'lat': 59.940953,
#     'lon': 10.720862,
#     'capacity': 42},
#    {'station_id': '477',
#     'name': 'Møllergata',
#     'address': 'Møllergata',
#     'lat': 59.9154413,
#     'lon': 10.7485819,
#     'capacity': 27},
#    {'station_id': '580',
#     'name': 'Georg Morgenstiernes hus',
#     'address': 'Blindern  Moltke Moes vei',
#     'lat': 59.9390363,
#     'lon': 10.7229302,
#     'capacity': 45},
#    {'station_id': '496',
#     'name': 'Fysikkbygningen',
#     'address': 'Blindern Fysikkbygg',
#     'lat': 59.9379399,
#     'lon': 10.7195985,
#     'capacity': 45},
#    {'station_id': '482',
#     'name': 'Nydalen',
#     'address': 'Nydalen/Gjerdrumsvei 6',
#     'lat': 59.952868,
#     'lon': 10.766483,
#     'capacity': 18},
#    {'station_id': '407',
#     'name': 'Sagene bussholdeplass',
#     'address': 'Sagene bussholdeplass',
#     'lat': 59.937743,
#     'lon': 10.751648,
#     'capacity': 15},
#    {'station_id': '409',
#     'name': 'John Colletts plass',
#     'address': 'Sognsveien',
#     'lat': 59.940398,
#     'lon': 10.730036,
#     'capacity': 25},
#    {'station_id': '451',
#     'name': 'Suhms gate',
#     'address': 'Suhms gate',
#     'lat': 59.929419,
#     'lon': 10.726195,
#     'capacity': 21},
#    {'station_id': '385',
#     'name': 'Søndre gate',
#     'address': 'Søndregate',
#     'lat': 59.918632,
#     'lon': 10.757867,
#     'capacity': 21},
#    {'station_id': '402',
#     'name': 'Lørenveien',
#     'address': 'Lørenveien',
#     'lat': 59.93087712510462,
#     'lon': 10.791823716034969,
#     'capacity': 21},
#    {'station_id': '516',
#     'name': 'Finnmarksgata',
#     'address': 'Finnmarksgata',
#     'lat': 59.922839,
#     'lon': 10.775658,
#     'capacity': 15},
#    {'station_id': '625',
#     'name': 'Spikersuppa Øst',
#     'address': 'spikersuppa',
#     'lat': 59.91336,
#     'lon': 10.737663,
#     'capacity': 42},
#    {'station_id': '429',
#     'name': 'Thune',
#     'address': 'Thune ved bomring',
#     'lat': 59.92208,
#     'lon': 10.68588,
#     'capacity': 21},
#    {'station_id': '380',
#     'name': 'Bentsebrugata',
#     'address': 'Bentsebrugata',
#     'lat': 59.93923,
#     'lon': 10.75917,
#     'capacity': 24},
#    {'station_id': '583',
#     'name': 'Galgeberg',
#     'address': 'St Halvors gate',
#     'lat': 59.9071,
#     'lon': 10.77921,
#     'capacity': 18},
#    {'station_id': '398',
#     'name': 'Ringnes Park',
#     'address': 'Ringen kino',
#     'lat': 59.92843404417577,
#     'lon': 10.75943014633117,
#     'capacity': 18},
#    {'station_id': '381',
#     'name': 'Grønlands torg',
#     'address': 'Grønlands torg',
#     'lat': 59.91252,
#     'lon': 10.76224,
#     'capacity': 15},
#    {'station_id': '464',
#     'name': 'Sukkerbiten',
#     'address': 'sukkerbiten',
#     'lat': 59.90580676630004,
#     'lon': 10.753656509579287,
#     'capacity': 39},
#    {'station_id': '442',
#     'name': 'Vulkan',
#     'address': 'Vulkan (Maridalsveien)',
#     'lat': 59.92251,
#     'lon': 10.75101,
#     'capacity': 18},
#    {'station_id': '483',
#     'name': 'Hausmanns gate',
#     'address': 'Hausmanns gate / Røde Kors',
#     'lat': 59.915451,
#     'lon': 10.758328,
#     'capacity': 21},
#    {'station_id': '458',
#     'name': 'Jenny Braatens Plass',
#     'address': 'Sinsenveien / Trondheimsveien',
#     'lat': 59.928349,
#     'lon': 10.77837,
#     'capacity': 15},
#    {'station_id': '499',
#     'name': 'Bjerregaards gate',
#     'address': 'Bjerregaards gate',
#     'lat': 59.925488,
#     'lon': 10.746058,
#     'capacity': 21},
#    {'station_id': '472',
#     'name': 'Arendalsgata',
#     'address': 'Arendalsgata / Sagene Kirke',
#     'lat': 59.9378,
#     'lon': 10.7541,
#     'capacity': 24},
#    {'station_id': '506',
#     'name': 'Botanisk Hage vest',
#     'address': 'Botanisk Hage vest',
#     'lat': 59.920073,
#     'lon': 10.769035,
#     'capacity': 27},
#    {'station_id': '465',
#     'name': 'Bjørvika',
#     'address': 'Bjørvika',
#     'lat': 59.909006,
#     'lon': 10.75618,
#     'capacity': 30},
#    {'station_id': '611',
#     'name': 'Bankplassen',
#     'address': 'Bankplassen',
#     'lat': 59.908454,
#     'lon': 10.741869,
#     'capacity': 39},
#    {'station_id': '404',
#     'name': 'Oslo Handelsgymnasium',
#     'address': 'Solligata',
#     'lat': 59.914306,
#     'lon': 10.720202,
#     'capacity': 27},
#    {'station_id': '579',
#     'name': 'Bogstadveien',
#     'address': 'Bogstadveien',
#     'lat': 59.924732,
#     'lon': 10.724628,
#     'capacity': 18},
#    {'station_id': '589',
#     'name': 'Huk',
#     'address': 'Huk',
#     'lat': 59.898126,
#     'lon': 10.675096,
#     'capacity': 48},
#    {'station_id': '434',
#     'name': 'Lindern',
#     'address': 'Kirkeveien 163',
#     'lat': 59.9358883,
#     'lon': 10.7350062,
#     'capacity': 21},
#    {'station_id': '462',
#     'name': 'Stensparken',
#     'address': 'Sporveisgata',
#     'lat': 59.92714,
#     'lon': 10.730981,
#     'capacity': 15},
#    {'station_id': '578',
#     'name': 'Hallings gate',
#     'address': 'Hallings gate',
#     'lat': 59.922777,
#     'lon': 10.738655,
#     'capacity': 24},
#    {'station_id': '415',
#     'name': 'Sinsenveien',
#     'address': 'Sinsenveien ',
#     'lat': 59.929542,
#     'lon': 10.781053,
#     'capacity': 12},
#    {'station_id': '423',
#     'name': 'Schous plass',
#     'address': 'Schous plass, stativ 2',
#     'lat': 59.920335,
#     'lon': 10.760804,
#     'capacity': 20},
#    {'station_id': '412',
#     'name': 'Jakob kirke',
#     'address': 'Jakob Kirke',
#     'lat': 59.917866,
#     'lon': 10.754898,
#     'capacity': 9},
#    {'station_id': '387',
#     'name': 'Studenterlunden',
#     'address': 'Karl Johans gate 47',
#     'lat': 59.914586,
#     'lon': 10.735453,
#     'capacity': 15},
#    {'station_id': '405',
#     'name': 'Frognerbadet',
#     'address': 'Frogner Stadion',
#     'lat': 59.92808,
#     'lon': 10.708767,
#     'capacity': 18},
#    {'station_id': '441',
#     'name': 'Vippetangen øst',
#     'address': 'Vippetangen_Akershusstranden',
#     'lat': 59.903989,
#     'lon': 10.741077,
#     'capacity': 15},
#    {'station_id': '443',
#     'name': 'Sjøsiden ved trappen',
#     'address': 'Sentralstasjonen Øst',
#     'lat': 59.910178,
#     'lon': 10.751824,
#     'capacity': 45},
#    {'station_id': '454',
#     'name': 'Furulund',
#     'address': 'Furulund',
#     'lat': 59.9198098,
#     'lon': 10.651118,
#     'capacity': 24},
#    {'station_id': '436',
#     'name': 'Vestkanttorvet',
#     'address': 'Vestkanttorvet',
#     'lat': 59.9244031,
#     'lon': 10.7130691,
#     'capacity': 15},
#    {'station_id': '394',
#     'name': 'Bjølsen Studentby',
#     'address': 'Bjølsen Studentby',
#     'lat': 59.94375,
#     'lon': 10.7603062,
#     'capacity': 21},
#    {'station_id': '497',
#     'name': 'Sirkustomta',
#     'address': 'Sirkustomta',
#     'lat': 59.919252,
#     'lon': 10.774712,
#     'capacity': 27},
#    {'station_id': '581',
#     'name': 'Jordalgata',
#     'address': 'Jordalgata- Galgeberg',
#     'lat': 59.908227,
#     'lon': 10.781088,
#     'capacity': 24},
#    {'station_id': '461',
#     'name': 'Vålerenga',
#     'address': 'Vålerenga',
#     'lat': 59.908576,
#     'lon': 10.786856,
#     'capacity': 21},
#    {'station_id': '599',
#     'name': 'Paléhaven',
#     'address': 'Palehaven',
#     'lat': 59.910331,
#     'lon': 10.75011,
#     'capacity': 48},
#    {'station_id': '400',
#     'name': 'HiOA',
#     'address': 'HiOA',
#     'lat': 59.919927,
#     'lon': 10.735428,
#     'capacity': 25},
#    {'station_id': '438',
#     'name': 'BI Nydalen',
#     'address': 'BI Nydalen\xa0',
#     'lat': 59.949239,
#     'lon': 10.768576,
#     'capacity': 42},
#    {'station_id': '459',
#     'name': 'Valkyrieplassen',
#     'address': 'Valkyrieplassen',
#     'lat': 59.9281319,
#     'lon': 10.71842,
#     'capacity': 12},
#    {'station_id': '433',
#     'name': 'Ila',
#     'address': "Ovenfor Claus Riis' gate",
#     'lat': 59.931828,
#     'lon': 10.748745,
#     'capacity': 18},
#    {'station_id': '399',
#     'name': 'Uelands gate',
#     'address': 'Uelands gate',
#     'lat': 59.929545,
#     'lon': 10.7489862,
#     'capacity': 36},
#    {'station_id': '489',
#     'name': 'Torggata',
#     'address': 'Torggata',
#     'lat': 59.916012,
#     'lon': 10.751655,
#     'capacity': 30},
#    {'station_id': '742',
#     'name': 'Hasle',
#     'address': 'Hasle',
#     'lat': 59.924342,
#     'lon': 10.79285,
#     'capacity': 30},
#    {'station_id': '551',
#     'name': 'Olaf Ryes plass',
#     'address': 'Olaf Ryes plass',
#     'lat': 59.922425,
#     'lon': 10.758182,
#     'capacity': 35},
#    {'station_id': '406',
#     'name': 'Carl Berners plass sør',
#     'address': 'Carl Berners plass\n',
#     'lat': 59.92507,
#     'lon': 10.775996,
#     'capacity': 12},
#    {'station_id': '488',
#     'name': 'Torshovparken vest',
#     'address': 'Torshovparken',
#     'lat': 59.93507,
#     'lon': 10.76915,
#     'capacity': 24},
#    {'station_id': '540',
#     'name': 'Lilleborgbanen',
#     'address': 'Lilleborgbanen',
#     'lat': 59.933727,
#     'lon': 10.769094,
#     'capacity': 36},
#    {'station_id': '431',
#     'name': 'Chr. Michelsens Gate',
#     'address': 'Chr. Michelsens Gate',
#     'lat': 59.927292,
#     'lon': 10.773185,
#     'capacity': 20},
#    {'station_id': '393',
#     'name': 'Hans Nielsen Hauges plass',
#     'address': 'Hans Nielsen Hauges plass',
#     'lat': 59.939244,
#     'lon': 10.774319,
#     'capacity': 21},
#    {'station_id': '420',
#     'name': 'Bjølsendumpa',
#     'address': 'Bjølsendumpa',
#     'lat': 59.94034,
#     'lon': 10.766079,
#     'capacity': 21},
#    {'station_id': '397',
#     'name': 'Storo Storsenter',
#     'address': 'Storo Storsenter',
#     'lat': 59.946695,
#     'lon': 10.773871,
#     'capacity': 42},
#    {'station_id': '449',
#     'name': 'Ruseløkkgården',
#     'address': 'Ruseløkkgården',
#     'lat': 59.913499,
#     'lon': 10.72656,
#     'capacity': 24},
#    {'station_id': '484',
#     'name': 'Karenlyst allé',
#     'address': 'Karenlyst allé',
#     'lat': 59.92033,
#     'lon': 10.683814,
#     'capacity': 35},
#    {'station_id': '479',
#     'name': 'Tjuvholmen',
#     'address': 'Tjuvholmen',
#     'lat': 59.909467,
#     'lon': 10.722509,
#     'capacity': 30},
#    {'station_id': '403',
#     'name': 'Parkveien',
#     'address': 'Parkveien',
#     'lat': 59.921768,
#     'lon': 10.730476,
#     'capacity': 15},
#    {'station_id': '435',
#     'name': 'Fram-gården',
#     'address': 'Fram-gården',
#     'lat': 59.915424,
#     'lon': 10.714577,
#     'capacity': 30},
#    {'station_id': '426',
#     'name': 'Gimle Kino',
#     'address': 'Gimle Kino',
#     'lat': 59.917202,
#     'lon': 10.708339,
#     'capacity': 21},
#    {'station_id': '450',
#     'name': 'Elisenberg',
#     'address': 'Elisenberg',
#     'lat': 59.919524,
#     'lon': 10.70884,
#     'capacity': 15},
#    {'station_id': '456',
#     'name': 'Frognerstranda',
#     'address': 'Frognerstranda ',
#     'lat': 59.9103558,
#     'lon': 10.7051061,
#     'capacity': 60},
#    {'station_id': '468',
#     'name': 'Skillebekk',
#     'address': 'Skillebekk',
#     'lat': 59.912742,
#     'lon': 10.710136,
#     'capacity': 15},
#    {'station_id': '453',
#     'name': 'Frogner Stadion',
#     'address': 'Frogner Stadion',
#     'lat': 59.927596,
#     'lon': 10.710033,
#     'capacity': 36},
#    {'station_id': '466',
#     'name': 'Ullevålsalléen',
#     'address': 'Ullevålsalléen',
#     'lat': 59.937913,
#     'lon': 10.73048,
#     'capacity': 15},
#    {'station_id': '469',
#     'name': 'Studentparlamentet',
#     'address': 'Studentparlamentet',
#     'lat': 59.920852,
#     'lon': 10.733357,
#     'capacity': 30},
#    {'station_id': '416',
#     'name': 'Tannlegehøyskolen',
#     'address': 'Tannlegehøyskolen',
#     'lat': 59.932383,
#     'lon': 10.741475,
#     'capacity': 15},
#    {'station_id': '391',
#     'name': 'St. Hanshaugen park vest',
#     'address': 'St. Hanshaugen Vest',
#     'lat': 59.9268706,
#     'lon': 10.7384634,
#     'capacity': 20},
#    {'station_id': '389',
#     'name': 'Pilestredet Studenthus',
#     'address': 'Pilestredet Studenthus',
#     'lat': 59.9205528,
#     'lon': 10.7342854,
#     'capacity': 18},
#    {'station_id': '470',
#     'name': 'St. Hanshaugen park nord',
#     'address': 'St. Hanshaugen Nord',
#     'lat': 59.929771,
#     'lon': 10.743524,
#     'capacity': 15},
#    {'station_id': '384',
#     'name': 'Vår Frelsers gravlund sør',
#     'address': 'Vår Frelsers Gravlund sør',
#     'lat': 59.919463,
#     'lon': 10.743829,
#     'capacity': 18},
#    {'station_id': '425',
#     'name': 'Adamstuen',
#     'address': 'Adamstuen',
#     'lat': 59.932792,
#     'lon': 10.734457,
#     'capacity': 8},
#    {'station_id': '411',
#     'name': 'Hasle Torg',
#     'address': 'Hasle Torg',
#     'lat': 59.9232266,
#     'lon': 10.7928824,
#     'capacity': 24},
#    {'station_id': '598',
#     'name': 'Sofienbergparken nord',
#     'address': 'Sofienbergparken nord',
#     'lat': 59.923229,
#     'lon': 10.766171,
#     'capacity': 33},
#    {'station_id': '447',
#     'name': 'Kværnerbyen',
#     'address': 'Kværnerbyen',
#     'lat': 59.904473,
#     'lon': 10.786167,
#     'capacity': 30},
#    {'station_id': '408',
#     'name': 'Tøyen skole',
#     'address': 'Tøyen skole',
#     'lat': 59.914943,
#     'lon': 10.773977,
#     'capacity': 15},
#    {'station_id': '737',
#     'name': 'Munkegata trikkestopp',
#     'address': 'Munkegata',
#     'lat': 59.908255,
#     'lon': 10.7678,
#     'capacity': 24},
#    {'station_id': '432',
#     'name': 'St. Hanshaugen park sør',
#     'address': 'St. Hanshaugen Sør',
#     'lat': 59.924821,
#     'lon': 10.739909,
#     'capacity': 12},
#    {'station_id': '401',
#     'name': 'Schous plass',
#     'address': 'Schous Plass.',
#     'lat': 59.920259,
#     'lon': 10.760629,
#     'capacity': 6},
#    {'station_id': '452',
#     'name': 'Vippetangen vest',
#     'address': 'Vippetangen',
#     'lat': 59.903989,
#     'lon': 10.740627,
#     'capacity': 30},
#    {'station_id': '392',
#     'name': 'Sjøsiden ved fontenen',
#     'address': 'Sentralstasjonen Vest',
#     'lat': 59.910180852633516,
#     'lon': 10.751698750995615,
#     'capacity': 50},
#    {'station_id': '481',
#     'name': 'Rådhusgata',
#     'address': 'Rådhusgata',
#     'lat': 59.910924,
#     'lon': 10.736215,
#     'capacity': 42},
#    {'station_id': '495',
#     'name': 'Vaterlandsparken',
#     'address': 'Vaterlandsparken',
#     'lat': 59.91351552854147,
#     'lon': 10.757334670552268,
#     'capacity': 41},
#    {'station_id': '478',
#     'name': 'Jernbanetorget',
#     'address': 'Jernbanetorget',
#     'lat': 59.911901,
#     'lon': 10.749929,
#     'capacity': 15},
#    {'station_id': '448',
#     'name': 'Oslo Plaza',
#     'address': 'Oslo Plaza',
#     'lat': 59.912185,
#     'lon': 10.754506,
#     'capacity': 9},
#    {'station_id': '414',
#     'name': 'Kontraskjæret',
#     'address': 'Kontraskjæret',
#     'lat': 59.910242,
#     'lon': 10.73857,
#     'capacity': 12},
#    {'station_id': '476',
#     'name': 'Edvard Storms gate',
#     'address': 'Pilestredet Edvard Storms',
#     'lat': 59.919111,
#     'lon': 10.736179,
#     'capacity': 20},
#    {'station_id': '445',
#     'name': 'Sjølyst',
#     'address': 'Sjølyst',
#     'lat': 59.921673,
#     'lon': 10.67666,
#     'capacity': 18},
#    {'station_id': '748',
#     'name': 'Hydroparken',
#     'address': 'Hydroparken ',
#     'lat': 59.914145,
#     'lon': 10.715505,
#     'capacity': 30},
#    {'station_id': '473',
#     'name': 'Majorstuveien',
#     'address': 'Majorstuveien',
#     'lat': 59.926697,
#     'lon': 10.716195,
#     'capacity': 9},
#    {'station_id': '383',
#     'name': 'Arkitekt Rivertz Plass',
#     'address': 'Arkitekt Rivertz Plass',
#     'lat': 59.934936,
#     'lon': 10.749466,
#     'capacity': 30},
#    {'station_id': '480',
#     'name': 'Helga Helgesens plass',
#     'address': 'Helga Helgesens plass',
#     'lat': 59.9121109,
#     'lon': 10.7661939,
#     'capacity': 25},
#    {'station_id': '421',
#     'name': 'Alexander Kiellands Plass',
#     'address': 'Alexander Kiellands Plass',
#     'lat': 59.928058,
#     'lon': 10.751397,
#     'capacity': 25},
#    {'station_id': '746',
#     'name': 'Bygdøy allé',
#     'address': 'Bygdøy allé ',
#     'lat': 59.919001,
#     'lon': 10.692321,
#     'capacity': 12},
#    {'station_id': '386',
#     'name': 'Slemdalsveien',
#     'address': 'Majorstuen T-bane, side Slemdalsveien ',
#     'lat': 59.930596,
#     'lon': 10.714778,
#     'capacity': 18},
#    {'station_id': '378',
#     'name': 'Colosseum Kino',
#     'address': 'Colosseum',
#     'lat': 59.929853,
#     'lon': 10.711515,
#     'capacity': 12},
#    {'station_id': '417',
#     'name': 'Uranienborgparken',
#     'address': 'Uranienborgparken',
#     'lat': 59.922485,
#     'lon': 10.720896,
#     'capacity': 15},
#    {'station_id': '427',
#     'name': 'Briskeby',
#     'address': 'Briskeby',
#     'lat': 59.920218,
#     'lon': 10.717978,
#     'capacity': 15},
#    {'station_id': '395',
#     'name': 'Frogner Tennisklubb',
#     'address': 'Frogner Tennisklubb',
#     'lat': 59.9261831,
#     'lon': 10.7098327,
#     'capacity': 15},
#    {'station_id': '418',
#     'name': 'Norsk Folkemuseum',
#     'address': 'Folkemuseet',
#     'lat': 59.907674,
#     'lon': 10.686843,
#     'capacity': 12},
#    {'station_id': '413',
#     'name': 'Majorstuen',
#     'address': 'Majorstuen',
#     'lat': 59.929045,
#     'lon': 10.716926,
#     'capacity': 18},
#    {'station_id': '486',
#     'name': 'Det Teologiske fakultet',
#     'address': 'Universitetet i Oslo',
#     'lat': 59.935342,
#     'lon': 10.726472,
#     'capacity': 28},
#    {'station_id': '471',
#     'name': 'Marienlyst',
#     'address': 'Suhms Gate 13_Harald Hårfagres Gate',
#     'lat': 59.932454,
#     'lon': 10.721769,
#     'capacity': 12},
#    {'station_id': '597',
#     'name': 'Fredensborg',
#     'address': 'Fredensborg',
#     'lat': 59.920995,
#     'lon': 10.750358,
#     'capacity': 15},
#    {'station_id': '422',
#     'name': 'St. Hanshaugen',
#     'address': 'St. Hanshaugen',
#     'lat': 59.923703,
#     'lon': 10.740542,
#     'capacity': 12},
#    {'station_id': '739',
#     'name': 'Hammersborg Torg',
#     'address': 'Møllergata 39',
#     'lat': 59.916536,
#     'lon': 10.749162,
#     'capacity': 20},
#    {'station_id': '382',
#     'name': 'Stensgata',
#     'address': 'Theresesgate_Stensgata',
#     'lat': 59.929634,
#     'lon': 10.732839,
#     'capacity': 9},
#    {'station_id': '396',
#     'name': 'Kirkeristen',
#     'address': 'Kirkeristen',
#     'lat': 59.913032,
#     'lon': 10.746681,
#     'capacity': 24},
#    {'station_id': '735',
#     'name': 'Oslo Hospital',
#     'address': 'Oslo Hospital',
#     'lat': 59.9031036,
#     'lon': 10.7673282,
#     'capacity': 15},
#    {'station_id': '437',
#     'name': 'Sentrum Scene',
#     'address': 'Sentrum Scene',
#     'lat': 59.91546786564256,
#     'lon': 10.751140873016311,
#     'capacity': 24},
#    {'station_id': '446',
#     'name': 'Bislett Stadion',
#     'address': 'Bislett Stadion',
#     'lat': 59.92549,
#     'lon': 10.731288,
#     'capacity': 24},
#    {'station_id': '424',
#     'name': 'Birkelunden',
#     'address': 'Seidluksgata Birkelunden',
#     'lat': 59.9256113,
#     'lon': 10.760926,
#     'capacity': 10},
#    {'station_id': '455',
#     'name': 'Sofienbergparken sør',
#     'address': 'Sofienbergparken sør',
#     'lat': 59.922337,
#     'lon': 10.7617503,
#     'capacity': 12},
#    {'station_id': '457',
#     'name': 'Trondheimsveien',
#     'address': 'Trondheimsveien 64',
#     'lat': 59.9230577,
#     'lon': 10.7717192,
#     'capacity': 10},
#    {'station_id': '377',
#     'name': 'Tøyenparken',
#     'address': 'Tøyenparken',
#     'lat': 59.915667,
#     'lon': 10.7775665,
#     'capacity': 29},
#    {'station_id': '738',
#     'name': 'Lodalen busstopp',
#     'address': 'Dyvekesvei_Konowsgate',
#     'lat': 59.9034528,
#     'lon': 10.777958,
#     'capacity': 12},
#    {'station_id': '460',
#     'name': 'Botanisk Hage sør',
#     'address': 'Tøyenhagen',
#     'lat': 59.9152819,
#     'lon': 10.7696199,
#     'capacity': 29},
#    {'station_id': '734',
#     'name': 'Nylandsveien',
#     'address': 'Nylandsveien',
#     'lat': 59.9156603,
#     'lon': 10.7622812,
#     'capacity': 30},
#    {'station_id': '744',
#     'name': 'Hallénparken',
#     'address': 'Johan Sverdrups Plass',
#     'lat': 59.9315302,
#     'lon': 10.762169,
#     'capacity': 10},
#    {'station_id': '485',
#     'name': 'Sommerfrydhagen',
#     'address': 'Sommerfrydhagen',
#     'lat': 59.911453,
#     'lon': 10.776072,
#     'capacity': 21}]}}

# %% [markdown]
# Ok, so our class from above was not ideal, it doesn't contain the metadata. To get this, we need to modify our code so that we  have an ID to information mapping. A good data structure for this would be a dictionary.

# %%
station_data = {}


def join_dicts(*dicts):
    joined = {}
    for dict in dicts:
        joined = {**joined, **dict}
    return joined


for single_station_metadata in station_metadata['data']['stations']:
    station_id = single_station_metadata['station_id']
    station_data[station_id] = single_station_metadata
    
for single_station_status in station_status['data']['stations']:
    station_id = single_station_status['station_id']
    station_data[station_id] = join_dicts(station_data[station_id], single_station_status)

# %%
station_data
# Out:
# {'1101': {'station_id': '1101',
#   'name': 'Stortingstunellen',
#   'address': 'Rådhusgata 34',
#   'lat': 59.91065301806209,
#   'lon': 10.737365277561025,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 20},
#  '1023': {'station_id': '1023',
#   'name': 'Professor Aschehougs plass',
#   'address': 'Professor Aschehougs plass',
#   'lat': 59.9147672,
#   'lon': 10.740971,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 10,
#   'num_docks_available': 2},
#  '1009': {'station_id': '1009',
#   'name': 'Borgenveien',
#   'address': 'Borgenveien',
#   'lat': 59.942742106473666,
#   'lon': 10.703833031254021,
#   'capacity': 10,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 10},
#  '970': {'station_id': '970',
#   'name': 'Enerhaugen',
#   'address': 'ved Sørligata',
#   'lat': 59.91320242563816,
#   'lon': 10.767579386407874,
#   'capacity': 25,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 23},
#  '787': {'station_id': '787',
#   'name': 'Kirkegata 15',
#   'address': 'Kirkegata 15, Oslo',
#   'lat': 59.91015615055511,
#   'lon': 10.743456971511705,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 0},
#  '627': {'station_id': '627',
#   'name': 'Skøyen Stasjon',
#   'address': 'Skøyen Stasjon',
#   'lat': 59.9226729,
#   'lon': 10.6788129,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 16,
#   'num_docks_available': 14},
#  '623': {'station_id': '623',
#   'name': '7 Juni Plassen',
#   'address': '7 Juni Plassen',
#   'lat': 59.9150596,
#   'lon': 10.7312715,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 17,
#   'num_docks_available': 1},
#  '624': {'station_id': '624',
#   'name': 'Dælenenggata',
#   'address': 'Dælenenggata ved Fagerheimgata',
#   'lat': 59.928716,
#   'lon': 10.7675618,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 20},
#  '626': {'station_id': '626',
#   'name': 'Drammensveien',
#   'address': 'Drammensveien 119',
#   'lat': 59.9204038,
#   'lon': 10.691147,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 20},
#  '614': {'station_id': '614',
#   'name': 'Sinsen T-bane',
#   'address': 'Sinsen t-bane',
#   'lat': 59.938808,
#   'lon': 10.780445,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '616': {'station_id': '616',
#   'name': 'Salt',
#   'address': 'Salt ved Langkaia',
#   'lat': 59.9069066,
#   'lon': 10.7466245,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 13,
#   'num_docks_available': 0},
#  '618': {'station_id': '618',
#   'name': 'Bak Niels Treschows hus sør',
#   'address': 'Bak Niels Treschows hus sør',
#   'lat': 59.9424323,
#   'lon': 10.723903,
#   'capacity': 42,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 41},
#  '621': {'station_id': '621',
#   'name': 'Torshovdalen øst',
#   'address': 'Torshovdalen øst',
#   'lat': 59.9328069,
#   'lon': 10.7774484,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 27},
#  '622': {'station_id': '622',
#   'name': 'Pilestredet 63',
#   'address': 'Pilestredet 63',
#   'lat': 59.9238826,
#   'lon': 10.7313627,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 28},
#  '613': {'station_id': '613',
#   'name': 'Schives gate',
#   'address': 'Schives gate',
#   'lat': 59.9208044,
#   'lon': 10.7140544,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 25},
#  '620': {'station_id': '620',
#   'name': 'Bislettgata',
#   'address': 'Bislettgata',
#   'lat': 59.9238336,
#   'lon': 10.7346377,
#   'capacity': 40,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 38},
#  '596': {'station_id': '596',
#   'name': 'Idioten',
#   'address': 'Idioten',
#   'lat': 59.9310814,
#   'lon': 10.7360029,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 18},
#  '617': {'station_id': '617',
#   'name': 'Bjerregaardsgate Øst',
#   'address': 'Bjerregaardsgate Øst',
#   'lat': 59.9272161,
#   'lon': 10.7497787,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 21},
#  '609': {'station_id': '609',
#   'name': 'Fred Olsens gate',
#   'address': 'Fred Olsens gate',
#   'lat': 59.9110506,
#   'lon': 10.7493737,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 23,
#   'num_docks_available': 4},
#  '607': {'station_id': '607',
#   'name': 'Marcus Thranes gate',
#   'address': 'Marcus Thranes gate',
#   'lat': 59.9327471,
#   'lon': 10.7585697,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 26},
#  '603': {'station_id': '603',
#   'name': 'Frogner plass',
#   'address': 'Frogner plass',
#   'lat': 59.9225392,
#   'lon': 10.7045406,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 15},
#  '590': {'station_id': '590',
#   'name': 'Majorstua skole',
#   'address': 'Majorstua skole',
#   'lat': 59.9294351,
#   'lon': 10.7136816,
#   'capacity': 40,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 40},
#  '610': {'station_id': '610',
#   'name': 'Sotahjørnet',
#   'address': 'Sotahjørnet',
#   'lat': 59.9099822,
#   'lon': 10.7914482,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 14},
#  '608': {'station_id': '608',
#   'name': 'Colletts gate',
#   'address': 'Colletts/Diriks gate',
#   'lat': 59.9307367,
#   'lon': 10.746379,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 20},
#  '593': {'station_id': '593',
#   'name': 'Bjølsen mølle',
#   'address': 'Bjølsen mølle',
#   'lat': 59.9392,
#   'lon': 10.768774,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 9,
#   'num_docks_available': 20},
#  '530': {'station_id': '530',
#   'name': 'Holbergs Plass',
#   'address': 'Holbergs Plass',
#   'lat': 59.9193095,
#   'lon': 10.7343051,
#   'capacity': 10,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 8},
#  '463': {'station_id': '463',
#   'name': 'Schous plass trikkestopp',
#   'address': 'Schous plass trikkestopp',
#   'lat': 59.9207284,
#   'lon': 10.7594857,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 18},
#  '475': {'station_id': '475',
#   'name': 'Hausmanns bru',
#   'address': 'Hausmanns bru',
#   'lat': 59.9146509,
#   'lon': 10.7598719,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 21},
#  '494': {'station_id': '494',
#   'name': 'Rådhusbrygge 4',
#   'address': 'Rådhusbrygge 4',
#   'lat': 59.9108469,
#   'lon': 10.7303766,
#   'capacity': 40,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 32},
#  '439': {'station_id': '439',
#   'name': 'Mølleparken',
#   'address': 'Mølleparken',
#   'lat': 59.9283928,
#   'lon': 10.7559693,
#   'capacity': 25,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 24},
#  '600': {'station_id': '600',
#   'name': 'Dyvekes bru',
#   'address': 'Dyvekes bru',
#   'lat': 59.905323,
#   'lon': 10.7689579,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 22},
#  '440': {'station_id': '440',
#   'name': 'Lakkegata',
#   'address': 'Lakkegata',
#   'lat': 59.9172088,
#   'lon': 10.7622135,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '612': {'station_id': '612',
#   'name': 'Ensjøveien',
#   'address': 'Ensjøveien',
#   'lat': 59.9167033,
#   'lon': 10.7833627,
#   'capacity': 19,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 6,
#   'num_docks_available': 13},
#  '491': {'station_id': '491',
#   'name': 'Brugata',
#   'address': 'Brugata 17',
#   'lat': 59.91366109486603,
#   'lon': 10.75729364846211,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 11,
#   'num_docks_available': 6},
#  '492': {'station_id': '492',
#   'name': 'Goethe Institut',
#   'address': 'Goethe Institut',
#   'lat': 59.9131792,
#   'lon': 10.7607798,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 9,
#   'num_docks_available': 3},
#  '493': {'station_id': '493',
#   'name': 'Sofienbergparken nordvest',
#   'address': 'Sofienbergparken nordvest',
#   'lat': 59.9243639,
#   'lon': 10.7615858,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 27},
#  '410': {'station_id': '410',
#   'name': 'Landstads gate',
#   'address': 'Circle K Kiellands',
#   'lat': 59.929005,
#   'lon': 10.7496755,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 26},
#  '605': {'station_id': '605',
#   'name': 'Økernveien',
#   'address': 'Økernveien ved bussholdeplass Ensjøveien\nØkernveien ved bussholdeplass Ensjøveien',
#   'lat': 59.9167376,
#   'lon': 10.779916,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '388': {'station_id': '388',
#   'name': 'Skovveien',
#   'address': 'Skovveien ved Frognerveien',
#   'lat': 59.9163309,
#   'lon': 10.716349,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 9},
#  '591': {'station_id': '591',
#   'name': 'Grenseveien',
#   'address': 'Grenseveien',
#   'lat': 59.9246227,
#   'lon': 10.7815924,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 16},
#  '592': {'station_id': '592',
#   'name': 'Badebakken',
#   'address': 'Maridalsveien / Badebakken',
#   'lat': 59.9455883,
#   'lon': 10.7604191,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 18},
#  '585': {'station_id': '585',
#   'name': 'Nordre gate',
#   'address': 'Nordre gate',
#   'lat': 59.9212171,
#   'lon': 10.7547918,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 15},
#  '565': {'station_id': '565',
#   'name': 'Mailundveien',
#   'address': 'Mailundveien - Rosenhoffgata',
#   'lat': 59.9309181,
#   'lon': 10.7728203,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 17},
#  '571': {'station_id': '571',
#   'name': 'Over Rådhusgata',
#   'address': 'Nedre Slottsgate 4',
#   'lat': 59.9101207,
#   'lon': 10.7407129,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 15,
#   'num_docks_available': 0},
#  '568': {'station_id': '568',
#   'name': 'Frognerveien',
#   'address': 'Frognerveien 15',
#   'lat': 59.9170851,
#   'lon': 10.7128796,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 11},
#  '588': {'station_id': '588',
#   'name': 'Meltzers gate',
#   'address': 'Meltzers gate ved Skovveien ',
#   'lat': 59.9180141,
#   'lon': 10.7184345,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 17},
#  '569': {'station_id': '569',
#   'name': 'Botanisk hage sør-vest',
#   'address': 'Sars gate',
#   'lat': 59.9177943,
#   'lon': 10.7662784,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 29},
#  '577': {'station_id': '577',
#   'name': 'Arkaden Nord',
#   'address': 'Dronningens gate ved Arkaden II',
#   'lat': 59.9121472,
#   'lon': 10.7480527,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 13,
#   'num_docks_available': 17},
#  '606': {'station_id': '606',
#   'name': 'Stockfleths gate',
#   'address': 'Stockfleths gate/ griffenfeldts',
#   'lat': 59.9339754,
#   'lon': 10.7521029,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '564': {'station_id': '564',
#   'name': 'Oscars gate',
#   'address': 'Oscars gate - Hegdehaugsveien',
#   'lat': 59.9224222,
#   'lon': 10.7272388,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 28},
#  '570': {'station_id': '570',
#   'name': 'Frøen T-bane',
#   'address': 'Frøen T-bane',
#   'lat': 59.9347352,
#   'lon': 10.7096985,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 13},
#  '572': {'station_id': '572',
#   'name': 'Skøyen',
#   'address': 'Skøyen (under bro)',
#   'lat': 59.922247,
#   'lon': 10.679738,
#   'capacity': 40,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 28,
#   'num_docks_available': 12},
#  '587': {'station_id': '587',
#   'name': 'Riddervoldplass',
#   'address': 'Riddervoldplass , Camilla Colletts vei',
#   'lat': 59.9191421,
#   'lon': 10.7196414,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '586': {'station_id': '586',
#   'name': 'Københavngata busstopp',
#   'address': 'Københavngata busstopp',
#   'lat': 59.9294754,
#   'lon': 10.769151,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 19},
#  '576': {'station_id': '576',
#   'name': 'Dronningens gate',
#   'address': 'Dronningens gate 25',
#   'lat': 59.91138423128484,
#   'lon': 10.747318039414154,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 15,
#   'num_docks_available': 3},
#  '566': {'station_id': '566',
#   'name': 'Hoff terrasse holdeplass',
#   'address': 'Hoffsveien - Engebrets vei',
#   'lat': 59.9272941,
#   'lon': 10.6755714,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 20,
#   'num_docks_available': 4},
#  '602': {'station_id': '602',
#   'name': 'Jarlsborgveien',
#   'address': 'Jarlsborgveien- Hoffsveien',
#   'lat': 59.9304645,
#   'lon': 10.6757833,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 18},
#  '575': {'station_id': '575',
#   'name': 'Sognsveien',
#   'address': 'Sognsveien ved Ullevål T-bane',
#   'lat': 59.9474863,
#   'lon': 10.7324195,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 29},
#  '567': {'station_id': '567',
#   'name': 'Forskningsveien',
#   'address': 'Forskningsveien',
#   'lat': 59.9454775,
#   'lon': 10.7138465,
#   'capacity': 39,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 36},
#  '582': {'station_id': '582',
#   'name': 'Stavangergata',
#   'address': 'Stavangergata',
#   'lat': 59.941108,
#   'lon': 10.7506048,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 17,
#   'num_docks_available': 12},
#  '595': {'station_id': '595',
#   'name': 'Skarpsnoparken',
#   'address': 'Skarpsnoparken',
#   'lat': 59.914871,
#   'lon': 10.701037,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 23},
#  '557': {'station_id': '557',
#   'name': 'Akersgata',
#   'address': 'Akersgata - Grensen',
#   'lat': 59.9141971,
#   'lon': 10.7428828,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 13},
#  '542': {'station_id': '542',
#   'name': 'Grünerhagen Nord',
#   'address': 'Fossveien - Sofienberggata',
#   'lat': 59.9224256,
#   'lon': 10.7554274,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 20},
#  '563': {'station_id': '563',
#   'name': 'Huitfeldts gate',
#   'address': 'Huitfeldts gate 24',
#   'lat': 59.9126844,
#   'lon': 10.7229003,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 13},
#  '558': {'station_id': '558',
#   'name': 'Dokkveien',
#   'address': 'Dokkveien',
#   'lat': 59.910974,
#   'lon': 10.7277001,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 13,
#   'num_docks_available': 2},
#  '552': {'station_id': '552',
#   'name': 'Trelastgata',
#   'address': 'Bjørvika / Trelastgata',
#   'lat': 59.907967,
#   'lon': 10.762621,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 12},
#  '555': {'station_id': '555',
#   'name': 'Griffenfeldts gate',
#   'address': 'Griffenfeldts gate - Colletts gate',
#   'lat': 59.9337026,
#   'lon': 10.7519299,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 14},
#  '573': {'station_id': '573',
#   'name': 'Tordenskiolds gate',
#   'address': 'Tordenskiolds gate - Otto Sverdrups gate',
#   'lat': 59.9117882,
#   'lon': 10.7351647,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 20,
#   'num_docks_available': 0},
#  '561': {'station_id': '561',
#   'name': 'Kirkeveien',
#   'address': 'Kirkeveien - Gørbitz gate\n',
#   'lat': 59.9335582,
#   'lon': 10.7264261,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '615': {'station_id': '615',
#   'name': 'Munkedamsveien',
#   'address': 'Konserthuset/Munkedamsveien',
#   'lat': 59.9135227,
#   'lon': 10.7301061,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 18,
#   'num_docks_available': 1},
#  '543': {'station_id': '543',
#   'name': 'Fyrstikktorget',
#   'address': 'Fyrstikktorget',
#   'lat': 59.9138347,
#   'lon': 10.7981175,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 9,
#   'num_docks_available': 9},
#  '554': {'station_id': '554',
#   'name': 'Tåsen Senter',
#   'address': 'Tåsen senter\n',
#   'lat': 59.952659,
#   'lon': 10.751165,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 6,
#   'num_docks_available': 15},
#  '574': {'station_id': '574',
#   'name': 'Annette Thommessens Plass',
#   'address': 'Annette Thommesens Plass\n',
#   'lat': 59.9107393,
#   'lon': 10.7609998,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 4,
#   'num_docks_available': 0},
#  '560': {'station_id': '560',
#   'name': 'Gaustad T-bane',
#   'address': 'Gaustad T-bane',
#   'lat': 59.945955,
#   'lon': 10.710392,
#   'capacity': 9,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 5},
#  '548': {'station_id': '548',
#   'name': 'Colbjørnsens gate',
#   'address': 'Colbjørnsens gate',
#   'lat': 59.917293,
#   'lon': 10.716796,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '559': {'station_id': '559',
#   'name': 'Hoffsveien',
#   'address': 'Hoffsveien',
#   'lat': 59.923898,
#   'lon': 10.6760339,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 15,
#   'num_docks_available': 3},
#  '545': {'station_id': '545',
#   'name': 'Arkaden Sør',
#   'address': 'Dronningens gate ved Arkaden\n',
#   'lat': 59.9119691,
#   'lon': 10.7478583,
#   'capacity': 39,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 26,
#   'num_docks_available': 13},
#  '550': {'station_id': '550',
#   'name': 'Thereses gate',
#   'address': "Therese's gate 49\n",
#   'lat': 59.9261462,
#   'lon': 10.7310355,
#   'capacity': 9,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 8},
#  '541': {'station_id': '541',
#   'name': 'Langkaia',
#   'address': 'rådhusgata / langkaia',
#   'lat': 59.9080552,
#   'lon': 10.7479977,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 6,
#   'num_docks_available': 2},
#  '527': {'station_id': '527',
#   'name': "Biskop Gunnerus' gate",
#   'address': 'Oslo City - Biskop Gunnerus gate\n',
#   'lat': 59.9123341,
#   'lon': 10.752292,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 2},
#  '529': {'station_id': '529',
#   'name': 'Friggfeltet',
#   'address': 'Slemdalsveien ved Frigg',
#   'lat': 59.9327726,
#   'lon': 10.7114661,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 19},
#  '553': {'station_id': '553',
#   'name': 'Skråninga',
#   'address': 'Skråninga',
#   'lat': 59.9139786,
#   'lon': 10.7474667,
#   'capacity': 25,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 23,
#   'num_docks_available': 0},
#  '549': {'station_id': '549',
#   'name': 'Linaaes gate',
#   'address': 'Møllergata 3',
#   'lat': 59.913832,
#   'lon': 10.7457018,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 9,
#   'num_docks_available': 12},
#  '526': {'station_id': '526',
#   'name': 'Lille Grensen',
#   'address': 'Lille Grensen - Akersgata 43',
#   'lat': 59.9138973,
#   'lon': 10.7423101,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 2},
#  '537': {'station_id': '537',
#   'name': 'St. Olavs gate',
#   'address': 'St.Olavs gate 21 - Pilestredet',
#   'lat': 59.9179859,
#   'lon': 10.7385805,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 17,
#   'num_docks_available': 3},
#  '547': {'station_id': '547',
#   'name': 'Skippergata',
#   'address': 'Skippergata - Karl Johans gate',
#   'lat': 59.9112227,
#   'lon': 10.7481976,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 12,
#   'num_docks_available': 18},
#  '528': {'station_id': '528',
#   'name': 'Nedre Slottsgate',
#   'address': 'Nedre Slottsgate 12',
#   'lat': 59.913245,
#   'lon': 10.743669,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 14,
#   'num_docks_available': 0},
#  '601': {'station_id': '601',
#   'name': 'Rolf Wickstrøms vei',
#   'address': 'Rolf Wickstrøms vei',
#   'lat': 59.9534114,
#   'lon': 10.7577241,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 12},
#  '533': {'station_id': '533',
#   'name': 'Sørvest for Slottsparken',
#   'address': 'Henrik Ibsens gate 40',
#   'lat': 59.915262,
#   'lon': 10.7253157,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 10},
#  '535': {'station_id': '535',
#   'name': 'Uranienborgveien',
#   'address': 'Uranienborgveien - Parkveien',
#   'lat': 59.9200421,
#   'lon': 10.726634,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 20},
#  '524': {'station_id': '524',
#   'name': 'Volvat',
#   'address': 'Sørkedalsveien ved Skeidar',
#   'lat': 59.9330951,
#   'lon': 10.7040189,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 20},
#  '519': {'station_id': '519',
#   'name': 'Thomas Heftyes plass',
#   'address': 'Bygdøy alle/Elisenbergveien',
#   'lat': 59.9185405,
#   'lon': 10.7039116,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 21},
#  '534': {'station_id': '534',
#   'name': 'Filipstadveien',
#   'address': 'Filipstadveien El-bilparkering/busslomme',
#   'lat': 59.9102277,
#   'lon': 10.7208788,
#   'capacity': 39,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 20,
#   'num_docks_available': 17},
#  '521': {'station_id': '521',
#   'name': 'Jess Carlsens gate',
#   'address': 'Jess Carlsens gate',
#   'lat': 59.9186359,
#   'lon': 10.7523939,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 8},
#  '518': {'station_id': '518',
#   'name': 'Ullevålsveien',
#   'address': 'Ullevålsveien 47 - Schwenssens gate',
#   'lat': 59.9246852,
#   'lon': 10.7395045,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 18},
#  '556': {'station_id': '556',
#   'name': 'Pilestredet',
#   'address': 'Pilestredet 75',
#   'lat': 59.9262242,
#   'lon': 10.7296246,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 18},
#  '525': {'station_id': '525',
#   'name': 'Myraløkka Øst',
#   'address': 'Bentsebrugata - Arendalsgata',
#   'lat': 59.937205,
#   'lon': 10.7605813,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 9},
#  '517': {'station_id': '517',
#   'name': 'Tåsenløkka',
#   'address': 'Uelands gate - Voldsløkka',
#   'lat': 59.9433939,
#   'lon': 10.7482848,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 16},
#  '523': {'station_id': '523',
#   'name': 'Tøyenbekken',
#   'address': 'Tøyenbekken',
#   'lat': 59.9115945,
#   'lon': 10.7617736,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 27},
#  '522': {'station_id': '522',
#   'name': 'Mandalls gate',
#   'address': 'Mandalls gate',
#   'lat': 59.9123469,
#   'lon': 10.7638147,
#   'capacity': 10,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 2},
#  '594': {'station_id': '594',
#   'name': 'Kampen park Øst',
#   'address': 'Kampen park øst',
#   'lat': 59.915182,
#   'lon': 10.782129,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 13},
#  '532': {'station_id': '532',
#   'name': 'Brynseng T-bane',
#   'address': 'Brynseng t-bane',
#   'lat': 59.909238,
#   'lon': 10.814199,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 18},
#  '509': {'station_id': '509',
#   'name': 'Kjeld Stubs gate',
#   'address': 'Kjeld Stubs gate',
#   'lat': 59.912711,
#   'lon': 10.735595,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 6,
#   'num_docks_available': 1},
#  '531': {'station_id': '531',
#   'name': 'Monolittveien',
#   'address': 'Smestaddammen (Monolittveien/Hoffsveien)',
#   'lat': 59.935947,
#   'lon': 10.681138,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 11},
#  '536': {'station_id': '536',
#   'name': 'Diakonhjemmet',
#   'address': 'Diakonhjemmet - Høyskolen',
#   'lat': 59.9363277,
#   'lon': 10.7054333,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 14},
#  '562': {'station_id': '562',
#   'name': 'Slottsparken Øst',
#   'address': 'St Olavsgate / Kristian IV gate',
#   'lat': 59.917485,
#   'lon': 10.732128,
#   'capacity': 40,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 27},
#  '511': {'station_id': '511',
#   'name': 'Henrik Ibsens gate',
#   'address': 'Parkveien / Henrik Ibsens gate',
#   'lat': 59.915088,
#   'lon': 10.7222803,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 19},
#  '505': {'station_id': '505',
#   'name': 'Marienlystparken',
#   'address': 'Marienlyst / Kirkeveien',
#   'lat': 59.93215,
#   'lon': 10.723478,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 23},
#  '501': {'station_id': '501',
#   'name': "Krebs' gate",
#   'address': "Krebs' gate / Vogstgate",
#   'lat': 59.935995,
#   'lon': 10.765413,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 18},
#  '514': {'station_id': '514',
#   'name': 'Sofienberggata',
#   'address': 'Sofienberggata / Trondheimsveien',
#   'lat': 59.9212063,
#   'lon': 10.7699892,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 12},
#  '500': {'station_id': '500',
#   'name': 'Anker Hostel',
#   'address': 'Storgata 57 Anker Hotell',
#   'lat': 59.9172794,
#   'lon': 10.7581553,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 17},
#  '503': {'station_id': '503',
#   'name': 'Fagerheimgata',
#   'address': 'Fagerheimgata / Malmøgata',
#   'lat': 59.9274634,
#   'lon': 10.7657433,
#   'capacity': 33,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 6,
#   'num_docks_available': 25},
#  '513': {'station_id': '513',
#   'name': 'Bøkkerveien',
#   'address': 'Hasle Linje / Bøkkerveien ved Cafe Nord',
#   'lat': 59.9273747,
#   'lon': 10.7960147,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '498': {'station_id': '498',
#   'name': 'HasleLinje',
#   'address': 'Hasle Linje / Karevsvingen ved BYM',
#   'lat': 59.9276408,
#   'lon': 10.7992011,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 16},
#  '507': {'station_id': '507',
#   'name': 'Jens Bjelkes gate',
#   'address': 'Jens Bjelkes gate / Trondheimsveien',
#   'lat': 59.919179,
#   'lon': 10.764162,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 10},
#  '512': {'station_id': '512',
#   'name': 'Ensjø T-bane',
#   'address': 'Ensjø t-bane',
#   'lat': 59.9131891,
#   'lon': 10.7897605,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 24},
#  '502': {'station_id': '502',
#   'name': 'Ullevål sykehus',
#   'address': 'Kirkeveien / Ullevål sykehus',
#   'lat': 59.9360307,
#   'lon': 10.7364516,
#   'capacity': 35,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 30},
#  '619': {'station_id': '619',
#   'name': 'Bak Niels Treschows hus nord',
#   'address': 'Bak Niels Treschows nord',
#   'lat': 59.942780248542554,
#   'lon': 10.722993731144015,
#   'capacity': 42,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 41},
#  '474': {'station_id': '474',
#   'name': 'Blindern studentparkering',
#   'address': 'Blindern studentparkering',
#   'lat': 59.940953,
#   'lon': 10.720862,
#   'capacity': 42,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 41},
#  '477': {'station_id': '477',
#   'name': 'Møllergata',
#   'address': 'Møllergata',
#   'lat': 59.9154413,
#   'lon': 10.7485819,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 19},
#  '580': {'station_id': '580',
#   'name': 'Georg Morgenstiernes hus',
#   'address': 'Blindern  Moltke Moes vei',
#   'lat': 59.9390363,
#   'lon': 10.7229302,
#   'capacity': 45,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 45},
#  '496': {'station_id': '496',
#   'name': 'Fysikkbygningen',
#   'address': 'Blindern Fysikkbygg',
#   'lat': 59.9379399,
#   'lon': 10.7195985,
#   'capacity': 45,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 45},
#  '482': {'station_id': '482',
#   'name': 'Nydalen',
#   'address': 'Nydalen/Gjerdrumsvei 6',
#   'lat': 59.952868,
#   'lon': 10.766483,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 15},
#  '407': {'station_id': '407',
#   'name': 'Sagene bussholdeplass',
#   'address': 'Sagene bussholdeplass',
#   'lat': 59.937743,
#   'lon': 10.751648,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 15},
#  '409': {'station_id': '409',
#   'name': 'John Colletts plass',
#   'address': 'Sognsveien',
#   'lat': 59.940398,
#   'lon': 10.730036,
#   'capacity': 25,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 25},
#  '451': {'station_id': '451',
#   'name': 'Suhms gate',
#   'address': 'Suhms gate',
#   'lat': 59.929419,
#   'lon': 10.726195,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 19},
#  '385': {'station_id': '385',
#   'name': 'Søndre gate',
#   'address': 'Søndregate',
#   'lat': 59.918632,
#   'lon': 10.757867,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 15},
#  '402': {'station_id': '402',
#   'name': 'Lørenveien',
#   'address': 'Lørenveien',
#   'lat': 59.93087712510462,
#   'lon': 10.791823716034969,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 21},
#  '516': {'station_id': '516',
#   'name': 'Finnmarksgata',
#   'address': 'Finnmarksgata',
#   'lat': 59.922839,
#   'lon': 10.775658,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 6,
#   'num_docks_available': 5},
#  '625': {'station_id': '625',
#   'name': 'Spikersuppa Øst',
#   'address': 'spikersuppa',
#   'lat': 59.91336,
#   'lon': 10.737663,
#   'capacity': 42,
#   'is_installed': 0,
#   'is_renting': 0,
#   'is_returning': 0,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 42},
#  '429': {'station_id': '429',
#   'name': 'Thune',
#   'address': 'Thune ved bomring',
#   'lat': 59.92208,
#   'lon': 10.68588,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 11,
#   'num_docks_available': 10},
#  '380': {'station_id': '380',
#   'name': 'Bentsebrugata',
#   'address': 'Bentsebrugata',
#   'lat': 59.93923,
#   'lon': 10.75917,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '583': {'station_id': '583',
#   'name': 'Galgeberg',
#   'address': 'St Halvors gate',
#   'lat': 59.9071,
#   'lon': 10.77921,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 16},
#  '398': {'station_id': '398',
#   'name': 'Ringnes Park',
#   'address': 'Ringen kino',
#   'lat': 59.92843404417577,
#   'lon': 10.75943014633117,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 12},
#  '381': {'station_id': '381',
#   'name': 'Grønlands torg',
#   'address': 'Grønlands torg',
#   'lat': 59.91252,
#   'lon': 10.76224,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 1},
#  '464': {'station_id': '464',
#   'name': 'Sukkerbiten',
#   'address': 'sukkerbiten',
#   'lat': 59.90580676630004,
#   'lon': 10.753656509579287,
#   'capacity': 39,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 33},
#  '442': {'station_id': '442',
#   'name': 'Vulkan',
#   'address': 'Vulkan (Maridalsveien)',
#   'lat': 59.92251,
#   'lon': 10.75101,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 16},
#  '483': {'station_id': '483',
#   'name': 'Hausmanns gate',
#   'address': 'Hausmanns gate / Røde Kors',
#   'lat': 59.915451,
#   'lon': 10.758328,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 14,
#   'num_docks_available': 1},
#  '458': {'station_id': '458',
#   'name': 'Jenny Braatens Plass',
#   'address': 'Sinsenveien / Trondheimsveien',
#   'lat': 59.928349,
#   'lon': 10.77837,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 10,
#   'num_docks_available': 5},
#  '499': {'station_id': '499',
#   'name': 'Bjerregaards gate',
#   'address': 'Bjerregaards gate',
#   'lat': 59.925488,
#   'lon': 10.746058,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 19},
#  '472': {'station_id': '472',
#   'name': 'Arendalsgata',
#   'address': 'Arendalsgata / Sagene Kirke',
#   'lat': 59.9378,
#   'lon': 10.7541,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '506': {'station_id': '506',
#   'name': 'Botanisk Hage vest',
#   'address': 'Botanisk Hage vest',
#   'lat': 59.920073,
#   'lon': 10.769035,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 24},
#  '465': {'station_id': '465',
#   'name': 'Bjørvika',
#   'address': 'Bjørvika',
#   'lat': 59.909006,
#   'lon': 10.75618,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 15,
#   'num_docks_available': 14},
#  '611': {'station_id': '611',
#   'name': 'Bankplassen',
#   'address': 'Bankplassen',
#   'lat': 59.908454,
#   'lon': 10.741869,
#   'capacity': 39,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 14,
#   'num_docks_available': 25},
#  '404': {'station_id': '404',
#   'name': 'Oslo Handelsgymnasium',
#   'address': 'Solligata',
#   'lat': 59.914306,
#   'lon': 10.720202,
#   'capacity': 27,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 20},
#  '579': {'station_id': '579',
#   'name': 'Bogstadveien',
#   'address': 'Bogstadveien',
#   'lat': 59.924732,
#   'lon': 10.724628,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 16},
#  '589': {'station_id': '589',
#   'name': 'Huk',
#   'address': 'Huk',
#   'lat': 59.898126,
#   'lon': 10.675096,
#   'capacity': 48,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 48},
#  '434': {'station_id': '434',
#   'name': 'Lindern',
#   'address': 'Kirkeveien 163',
#   'lat': 59.9358883,
#   'lon': 10.7350062,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 21},
#  '462': {'station_id': '462',
#   'name': 'Stensparken',
#   'address': 'Sporveisgata',
#   'lat': 59.92714,
#   'lon': 10.730981,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '578': {'station_id': '578',
#   'name': 'Hallings gate',
#   'address': 'Hallings gate',
#   'lat': 59.922777,
#   'lon': 10.738655,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '415': {'station_id': '415',
#   'name': 'Sinsenveien',
#   'address': 'Sinsenveien ',
#   'lat': 59.929542,
#   'lon': 10.781053,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 3},
#  '423': {'station_id': '423',
#   'name': 'Schous plass',
#   'address': 'Schous plass, stativ 2',
#   'lat': 59.920335,
#   'lon': 10.760804,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 14},
#  '412': {'station_id': '412',
#   'name': 'Jakob kirke',
#   'address': 'Jakob Kirke',
#   'lat': 59.917866,
#   'lon': 10.754898,
#   'capacity': 9,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 4},
#  '387': {'station_id': '387',
#   'name': 'Studenterlunden',
#   'address': 'Karl Johans gate 47',
#   'lat': 59.914586,
#   'lon': 10.735453,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 9,
#   'num_docks_available': 1},
#  '405': {'station_id': '405',
#   'name': 'Frognerbadet',
#   'address': 'Frogner Stadion',
#   'lat': 59.92808,
#   'lon': 10.708767,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 16},
#  '441': {'station_id': '441',
#   'name': 'Vippetangen øst',
#   'address': 'Vippetangen_Akershusstranden',
#   'lat': 59.903989,
#   'lon': 10.741077,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 8,
#   'num_docks_available': 7},
#  '443': {'station_id': '443',
#   'name': 'Sjøsiden ved trappen',
#   'address': 'Sentralstasjonen Øst',
#   'lat': 59.910178,
#   'lon': 10.751824,
#   'capacity': 45,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 18,
#   'num_docks_available': 26},
#  '454': {'station_id': '454',
#   'name': 'Furulund',
#   'address': 'Furulund',
#   'lat': 59.9198098,
#   'lon': 10.651118,
#   'capacity': 24,
#   'is_installed': 1,
# ...
#   'num_docks_available': 15},
#  '391': {'station_id': '391',
#   'name': 'St. Hanshaugen park vest',
#   'address': 'St. Hanshaugen Vest',
#   'lat': 59.9268706,
#   'lon': 10.7384634,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 17},
#  '389': {'station_id': '389',
#   'name': 'Pilestredet Studenthus',
#   'address': 'Pilestredet Studenthus',
#   'lat': 59.9205528,
#   'lon': 10.7342854,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 16},
#  '470': {'station_id': '470',
#   'name': 'St. Hanshaugen park nord',
#   'address': 'St. Hanshaugen Nord',
#   'lat': 59.929771,
#   'lon': 10.743524,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 11},
#  '384': {'station_id': '384',
#   'name': 'Vår Frelsers gravlund sør',
#   'address': 'Vår Frelsers Gravlund sør',
#   'lat': 59.919463,
#   'lon': 10.743829,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 17},
#  '425': {'station_id': '425',
#   'name': 'Adamstuen',
#   'address': 'Adamstuen',
#   'lat': 59.932792,
#   'lon': 10.734457,
#   'capacity': 8,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 5},
#  '411': {'station_id': '411',
#   'name': 'Hasle Torg',
#   'address': 'Hasle Torg',
#   'lat': 59.9232266,
#   'lon': 10.7928824,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 22},
#  '598': {'station_id': '598',
#   'name': 'Sofienbergparken nord',
#   'address': 'Sofienbergparken nord',
#   'lat': 59.923229,
#   'lon': 10.766171,
#   'capacity': 33,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 18,
#   'num_docks_available': 15},
#  '447': {'station_id': '447',
#   'name': 'Kværnerbyen',
#   'address': 'Kværnerbyen',
#   'lat': 59.904473,
#   'lon': 10.786167,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 29},
#  '408': {'station_id': '408',
#   'name': 'Tøyen skole',
#   'address': 'Tøyen skole',
#   'lat': 59.914943,
#   'lon': 10.773977,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 11},
#  '737': {'station_id': '737',
#   'name': 'Munkegata trikkestopp',
#   'address': 'Munkegata',
#   'lat': 59.908255,
#   'lon': 10.7678,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 17},
#  '432': {'station_id': '432',
#   'name': 'St. Hanshaugen park sør',
#   'address': 'St. Hanshaugen Sør',
#   'lat': 59.924821,
#   'lon': 10.739909,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 12},
#  '401': {'station_id': '401',
#   'name': 'Schous plass',
#   'address': 'Schous Plass.',
#   'lat': 59.920259,
#   'lon': 10.760629,
#   'capacity': 6,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 2},
#  '452': {'station_id': '452',
#   'name': 'Vippetangen vest',
#   'address': 'Vippetangen',
#   'lat': 59.903989,
#   'lon': 10.740627,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 25},
#  '392': {'station_id': '392',
#   'name': 'Sjøsiden ved fontenen',
#   'address': 'Sentralstasjonen Vest',
#   'lat': 59.910180852633516,
#   'lon': 10.751698750995615,
#   'capacity': 50,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 21,
#   'num_docks_available': 26},
#  '481': {'station_id': '481',
#   'name': 'Rådhusgata',
#   'address': 'Rådhusgata',
#   'lat': 59.910924,
#   'lon': 10.736215,
#   'capacity': 42,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 25,
#   'num_docks_available': 12},
#  '495': {'station_id': '495',
#   'name': 'Vaterlandsparken',
#   'address': 'Vaterlandsparken',
#   'lat': 59.91351552854147,
#   'lon': 10.757334670552268,
#   'capacity': 41,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 19,
#   'num_docks_available': 19},
#  '478': {'station_id': '478',
#   'name': 'Jernbanetorget',
#   'address': 'Jernbanetorget',
#   'lat': 59.911901,
#   'lon': 10.749929,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 11,
#   'num_docks_available': 0},
#  '448': {'station_id': '448',
#   'name': 'Oslo Plaza',
#   'address': 'Oslo Plaza',
#   'lat': 59.912185,
#   'lon': 10.754506,
#   'capacity': 9,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 6},
#  '414': {'station_id': '414',
#   'name': 'Kontraskjæret',
#   'address': 'Kontraskjæret',
#   'lat': 59.910242,
#   'lon': 10.73857,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 1},
#  '476': {'station_id': '476',
#   'name': 'Edvard Storms gate',
#   'address': 'Pilestredet Edvard Storms',
#   'lat': 59.919111,
#   'lon': 10.736179,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 2,
#   'num_docks_available': 18},
#  '445': {'station_id': '445',
#   'name': 'Sjølyst',
#   'address': 'Sjølyst',
#   'lat': 59.921673,
#   'lon': 10.67666,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 7,
#   'num_docks_available': 11},
#  '748': {'station_id': '748',
#   'name': 'Hydroparken',
#   'address': 'Hydroparken ',
#   'lat': 59.914145,
#   'lon': 10.715505,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 27},
#  '473': {'station_id': '473',
#   'name': 'Majorstuveien',
#   'address': 'Majorstuveien',
#   'lat': 59.926697,
#   'lon': 10.716195,
#   'capacity': 9,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 6},
#  '383': {'station_id': '383',
#   'name': 'Arkitekt Rivertz Plass',
#   'address': 'Arkitekt Rivertz Plass',
#   'lat': 59.934936,
#   'lon': 10.749466,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 27},
#  '480': {'station_id': '480',
#   'name': 'Helga Helgesens plass',
#   'address': 'Helga Helgesens plass',
#   'lat': 59.9121109,
#   'lon': 10.7661939,
#   'capacity': 25,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 5,
#   'num_docks_available': 14},
#  '421': {'station_id': '421',
#   'name': 'Alexander Kiellands Plass',
#   'address': 'Alexander Kiellands Plass',
#   'lat': 59.928058,
#   'lon': 10.751397,
#   'capacity': 25,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 24},
#  '746': {'station_id': '746',
#   'name': 'Bygdøy allé',
#   'address': 'Bygdøy allé ',
#   'lat': 59.919001,
#   'lon': 10.692321,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 9},
#  '386': {'station_id': '386',
#   'name': 'Slemdalsveien',
#   'address': 'Majorstuen T-bane, side Slemdalsveien ',
#   'lat': 59.930596,
#   'lon': 10.714778,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 15},
#  '378': {'station_id': '378',
#   'name': 'Colosseum Kino',
#   'address': 'Colosseum',
#   'lat': 59.929853,
#   'lon': 10.711515,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 11},
#  '417': {'station_id': '417',
#   'name': 'Uranienborgparken',
#   'address': 'Uranienborgparken',
#   'lat': 59.922485,
#   'lon': 10.720896,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 12},
#  '427': {'station_id': '427',
#   'name': 'Briskeby',
#   'address': 'Briskeby',
#   'lat': 59.920218,
#   'lon': 10.717978,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '395': {'station_id': '395',
#   'name': 'Frogner Tennisklubb',
#   'address': 'Frogner Tennisklubb',
#   'lat': 59.9261831,
#   'lon': 10.7098327,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 14},
#  '418': {'station_id': '418',
#   'name': 'Norsk Folkemuseum',
#   'address': 'Folkemuseet',
#   'lat': 59.907674,
#   'lon': 10.686843,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 11},
#  '413': {'station_id': '413',
#   'name': 'Majorstuen',
#   'address': 'Majorstuen',
#   'lat': 59.929045,
#   'lon': 10.716926,
#   'capacity': 18,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 16},
#  '486': {'station_id': '486',
#   'name': 'Det Teologiske fakultet',
#   'address': 'Universitetet i Oslo',
#   'lat': 59.935342,
#   'lon': 10.726472,
#   'capacity': 28,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 27},
#  '471': {'station_id': '471',
#   'name': 'Marienlyst',
#   'address': 'Suhms Gate 13_Harald Hårfagres Gate',
#   'lat': 59.932454,
#   'lon': 10.721769,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 9},
#  '597': {'station_id': '597',
#   'name': 'Fredensborg',
#   'address': 'Fredensborg',
#   'lat': 59.920995,
#   'lon': 10.750358,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 3,
#   'num_docks_available': 10},
#  '422': {'station_id': '422',
#   'name': 'St. Hanshaugen',
#   'address': 'St. Hanshaugen',
#   'lat': 59.923703,
#   'lon': 10.740542,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 10},
#  '739': {'station_id': '739',
#   'name': 'Hammersborg Torg',
#   'address': 'Møllergata 39',
#   'lat': 59.916536,
#   'lon': 10.749162,
#   'capacity': 20,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 14},
#  '382': {'station_id': '382',
#   'name': 'Stensgata',
#   'address': 'Theresesgate_Stensgata',
#   'lat': 59.929634,
#   'lon': 10.732839,
#   'capacity': 9,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 7},
#  '396': {'station_id': '396',
#   'name': 'Kirkeristen',
#   'address': 'Kirkeristen',
#   'lat': 59.913032,
#   'lon': 10.746681,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 16,
#   'num_docks_available': 4},
#  '735': {'station_id': '735',
#   'name': 'Oslo Hospital',
#   'address': 'Oslo Hospital',
#   'lat': 59.9031036,
#   'lon': 10.7673282,
#   'capacity': 15,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 10},
#  '437': {'station_id': '437',
#   'name': 'Sentrum Scene',
#   'address': 'Sentrum Scene',
#   'lat': 59.91546786564256,
#   'lon': 10.751140873016311,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 15,
#   'num_docks_available': 5},
#  '446': {'station_id': '446',
#   'name': 'Bislett Stadion',
#   'address': 'Bislett Stadion',
#   'lat': 59.92549,
#   'lon': 10.731288,
#   'capacity': 24,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 4,
#   'num_docks_available': 20},
#  '424': {'station_id': '424',
#   'name': 'Birkelunden',
#   'address': 'Seidluksgata Birkelunden',
#   'lat': 59.9256113,
#   'lon': 10.760926,
#   'capacity': 10,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 1,
#   'num_docks_available': 6},
#  '455': {'station_id': '455',
#   'name': 'Sofienbergparken sør',
#   'address': 'Sofienbergparken sør',
#   'lat': 59.922337,
#   'lon': 10.7617503,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 12},
#  '457': {'station_id': '457',
#   'name': 'Trondheimsveien',
#   'address': 'Trondheimsveien 64',
#   'lat': 59.9230577,
#   'lon': 10.7717192,
#   'capacity': 10,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 10},
#  '377': {'station_id': '377',
#   'name': 'Tøyenparken',
#   'address': 'Tøyenparken',
#   'lat': 59.915667,
#   'lon': 10.7775665,
#   'capacity': 29,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 29},
#  '738': {'station_id': '738',
#   'name': 'Lodalen busstopp',
#   'address': 'Dyvekesvei_Konowsgate',
#   'lat': 59.9034528,
#   'lon': 10.777958,
#   'capacity': 12,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 11},
#  '460': {'station_id': '460',
#   'name': 'Botanisk Hage sør',
#   'address': 'Tøyenhagen',
#   'lat': 59.9152819,
#   'lon': 10.7696199,
#   'capacity': 29,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 26},
#  '734': {'station_id': '734',
#   'name': 'Nylandsveien',
#   'address': 'Nylandsveien',
#   'lat': 59.9156603,
#   'lon': 10.7622812,
#   'capacity': 30,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 9,
#   'num_docks_available': 10},
#  '744': {'station_id': '744',
#   'name': 'Hallénparken',
#   'address': 'Johan Sverdrups Plass',
#   'lat': 59.9315302,
#   'lon': 10.762169,
#   'capacity': 10,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 4,
#   'num_docks_available': 4},
#  '485': {'station_id': '485',
#   'name': 'Sommerfrydhagen',
#   'address': 'Sommerfrydhagen',
#   'lat': 59.911453,
#   'lon': 10.776072,
#   'capacity': 21,
#   'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1574685724,
#   'num_bikes_available': 0,
#   'num_docks_available': 19}}

# %%
class Station:
    def __init__(
        self,
        station_id,
        is_installed,
        is_renting,
        is_returning,
        last_reported,
        num_bikes_available,
        num_docks_available,
        name,
        address,
        lat,
        lon,
        capacity
    ):
        self.station_id = station_id
        self.is_installed = is_installed
        self.is_renting = is_renting
        self.is_returning = is_returning
        self.last_reported = parse_time(last_reported)
        self.num_bikes_available = num_bikes_available
        self.num_docks_available = num_docks_available
        self.name = name
        self.address = address
        self.lat = lat
        self.lon = lon
        self.capacity = capacity

    def __repr__(self):
        return f'<Station {self.station_id}>'
    
    def __str__(self):
        return f"""\
        Station:
            ID: {self.station_id}
            Name: {self.name}
            Address: {self.address}
            Installed: {self.is_installed}
            Renting: {self.is_renting}
            Returning: {self.is_returning}
            Number of available bikes: {self.num_bikes_available}
            Number of available docking stations: {self.num_docks_available}
            Capcity: {self.capacity}
            Latitude: {self.lat}
            Longitude: {self.lon}
            Last reported: {self.last_reported}
            """
    
    
stations = {
    station_id: Station(**station_info) for station_id, station_info in station_data.items()
}

# %% [markdown]
# Is the station names unique?

# %%
names = {station_info['name'] for station_info in station_data.values()}
len(names), len(station_data)
# Out:
# (244, 245)

# %% [markdown]
# There are two stations with the same name

# %%
from collections import defaultdict


class StationsDatabase:
    def __init__(self, stations):
        self.names_to_id = defaultdict(list)
        for station_id, station_data in stations.items():
            self.names_to_id[station_data.name].append(station_id)
        
        self.stations = stations
    
    def show_location_info(self, name):
        if name not in self.names_to_id:
            raise NameError(f'{name} is not a valid name for a station')
        for station_id in self.names_to_id[name]:
            print(self.stations[station_id])

# %%
stations_database = StationsDatabase(stations)
stations_database.show_location_info('Bislettgata')
# Out:
#         Station:
#             ID: 620
#             Name: Bislettgata
#             Address: Bislettgata
#             Installed: 1
#             Renting: 1
#             Returning: 1
#             Number of available bikes: 0
#             Number of available docking stations: 38
#             Capcity: 40
#             Latitude: 59.9238336
#             Longitude: 10.7346377
#             Last reported: 2019-11-25 13:42:04

# %%
stations_database.names_to_id
# Out:
# defaultdict(list,
#             {'Stortingstunellen': ['1101'],
#              'Professor Aschehougs plass': ['1023'],
#              'Borgenveien': ['1009'],
#              'Enerhaugen': ['970'],
#              'Kirkegata 15': ['787'],
#              'Skøyen Stasjon': ['627'],
#              '7 Juni Plassen': ['623'],
#              'Dælenenggata': ['624'],
#              'Drammensveien': ['626'],
#              'Sinsen T-bane': ['614'],
#              'Salt': ['616'],
#              'Bak Niels Treschows hus sør': ['618'],
#              'Torshovdalen øst': ['621'],
#              'Pilestredet 63': ['622'],
#              'Schives gate': ['613'],
#              'Bislettgata': ['620'],
#              'Idioten': ['596'],
#              'Bjerregaardsgate Øst': ['617'],
#              'Fred Olsens gate': ['609'],
#              'Marcus Thranes gate': ['607'],
#              'Frogner plass': ['603'],
#              'Majorstua skole': ['590'],
#              'Sotahjørnet': ['610'],
#              'Colletts gate': ['608'],
#              'Bjølsen mølle': ['593'],
#              'Holbergs Plass': ['530'],
#              'Schous plass trikkestopp': ['463'],
#              'Hausmanns bru': ['475'],
#              'Rådhusbrygge 4': ['494'],
#              'Mølleparken': ['439'],
#              'Dyvekes bru': ['600'],
#              'Lakkegata': ['440'],
#              'Ensjøveien': ['612'],
#              'Brugata': ['491'],
#              'Goethe Institut': ['492'],
#              'Sofienbergparken nordvest': ['493'],
#              'Landstads gate': ['410'],
#              'Økernveien': ['605'],
#              'Skovveien': ['388'],
#              'Grenseveien': ['591'],
#              'Badebakken': ['592'],
#              'Nordre gate': ['585'],
#              'Mailundveien': ['565'],
#              'Over Rådhusgata': ['571'],
#              'Frognerveien': ['568'],
#              'Meltzers gate': ['588'],
#              'Botanisk hage sør-vest': ['569'],
#              'Arkaden Nord': ['577'],
#              'Stockfleths gate': ['606'],
#              'Oscars gate': ['564'],
#              'Frøen T-bane': ['570'],
#              'Skøyen': ['572'],
#              'Riddervoldplass': ['587'],
#              'Københavngata busstopp': ['586'],
#              'Dronningens gate': ['576'],
#              'Hoff terrasse holdeplass': ['566'],
#              'Jarlsborgveien': ['602'],
#              'Sognsveien': ['575'],
#              'Forskningsveien': ['567'],
#              'Stavangergata': ['582'],
#              'Skarpsnoparken': ['595'],
#              'Akersgata': ['557'],
#              'Grünerhagen Nord': ['542'],
#              'Huitfeldts gate': ['563'],
#              'Dokkveien': ['558'],
#              'Trelastgata': ['552'],
#              'Griffenfeldts gate': ['555'],
#              'Tordenskiolds gate': ['573'],
#              'Kirkeveien': ['561'],
#              'Munkedamsveien': ['615'],
#              'Fyrstikktorget': ['543'],
#              'Tåsen Senter': ['554'],
#              'Annette Thommessens Plass': ['574'],
#              'Gaustad T-bane': ['560'],
#              'Colbjørnsens gate': ['548'],
#              'Hoffsveien': ['559'],
#              'Arkaden Sør': ['545'],
#              'Thereses gate': ['550'],
#              'Langkaia': ['541'],
#              "Biskop Gunnerus' gate": ['527'],
#              'Friggfeltet': ['529'],
#              'Skråninga': ['553'],
#              'Linaaes gate': ['549'],
#              'Lille Grensen': ['526'],
#              'St. Olavs gate': ['537'],
#              'Skippergata': ['547'],
#              'Nedre Slottsgate': ['528'],
#              'Rolf Wickstrøms vei': ['601'],
#              'Sørvest for Slottsparken': ['533'],
#              'Uranienborgveien': ['535'],
#              'Volvat': ['524'],
#              'Thomas Heftyes plass': ['519'],
#              'Filipstadveien': ['534'],
#              'Jess Carlsens gate': ['521'],
#              'Ullevålsveien': ['518'],
#              'Pilestredet': ['556'],
#              'Myraløkka Øst': ['525'],
#              'Tåsenløkka': ['517'],
#              'Tøyenbekken': ['523'],
#              'Mandalls gate': ['522'],
#              'Kampen park Øst': ['594'],
#              'Brynseng T-bane': ['532'],
#              'Kjeld Stubs gate': ['509'],
#              'Monolittveien': ['531'],
#              'Diakonhjemmet': ['536'],
#              'Slottsparken Øst': ['562'],
#              'Henrik Ibsens gate': ['511'],
#              'Marienlystparken': ['505'],
#              "Krebs' gate": ['501'],
#              'Sofienberggata': ['514'],
#              'Anker Hostel': ['500'],
#              'Fagerheimgata': ['503'],
#              'Bøkkerveien': ['513'],
#              'HasleLinje': ['498'],
#              'Jens Bjelkes gate': ['507'],
#              'Ensjø T-bane': ['512'],
#              'Ullevål sykehus': ['502'],
#              'Bak Niels Treschows hus nord': ['619'],
#              'Blindern studentparkering': ['474'],
#              'Møllergata': ['477'],
#              'Georg Morgenstiernes hus': ['580'],
#              'Fysikkbygningen': ['496'],
#              'Nydalen': ['482'],
#              'Sagene bussholdeplass': ['407'],
#              'John Colletts plass': ['409'],
#              'Suhms gate': ['451'],
#              'Søndre gate': ['385'],
#              'Lørenveien': ['402'],
#              'Finnmarksgata': ['516'],
#              'Spikersuppa Øst': ['625'],
#              'Thune': ['429'],
#              'Bentsebrugata': ['380'],
#              'Galgeberg': ['583'],
#              'Ringnes Park': ['398'],
#              'Grønlands torg': ['381'],
#              'Sukkerbiten': ['464'],
#              'Vulkan': ['442'],
#              'Hausmanns gate': ['483'],
#              'Jenny Braatens Plass': ['458'],
#              'Bjerregaards gate': ['499'],
#              'Arendalsgata': ['472'],
#              'Botanisk Hage vest': ['506'],
#              'Bjørvika': ['465'],
#              'Bankplassen': ['611'],
#              'Oslo Handelsgymnasium': ['404'],
#              'Bogstadveien': ['579'],
#              'Huk': ['589'],
#              'Lindern': ['434'],
#              'Stensparken': ['462'],
#              'Hallings gate': ['578'],
#              'Sinsenveien': ['415'],
#              'Schous plass': ['423', '401'],
#              'Jakob kirke': ['412'],
#              'Studenterlunden': ['387'],
#              'Frognerbadet': ['405'],
#              'Vippetangen øst': ['441'],
#              'Sjøsiden ved trappen': ['443'],
#              'Furulund': ['454'],
#              'Vestkanttorvet': ['436'],
#              'Bjølsen Studentby': ['394'],
#              'Sirkustomta': ['497'],
#              'Jordalgata': ['581'],
#              'Vålerenga': ['461'],
#              'Paléhaven': ['599'],
#              'HiOA': ['400'],
#              'BI Nydalen': ['438'],
#              'Valkyrieplassen': ['459'],
#              'Ila': ['433'],
#              'Uelands gate': ['399'],
#              'Torggata': ['489'],
#              'Hasle': ['742'],
#              'Olaf Ryes plass': ['551'],
#              'Carl Berners plass sør': ['406'],
#              'Torshovparken vest': ['488'],
#              'Lilleborgbanen': ['540'],
#              'Chr. Michelsens Gate': ['431'],
#              'Hans Nielsen Hauges plass': ['393'],
#              'Bjølsendumpa': ['420'],
#              'Storo Storsenter': ['397'],
#              'Ruseløkkgården': ['449'],
#              'Karenlyst allé': ['484'],
#              'Tjuvholmen': ['479'],
#              'Parkveien': ['403'],
#              'Fram-gården': ['435'],
#              'Gimle Kino': ['426'],
#              'Elisenberg': ['450'],
#              'Frognerstranda': ['456'],
#              'Skillebekk': ['468'],
#              'Frogner Stadion': ['453'],
#              'Ullevålsalléen': ['466'],
#              'Studentparlamentet': ['469'],
#              'Tannlegehøyskolen': ['416'],
#              'St. Hanshaugen park vest': ['391'],
#              'Pilestredet Studenthus': ['389'],
#              'St. Hanshaugen park nord': ['470'],
#              'Vår Frelsers gravlund sør': ['384'],
#              'Adamstuen': ['425'],
#              'Hasle Torg': ['411'],
#              'Sofienbergparken nord': ['598'],
#              'Kværnerbyen': ['447'],
#              'Tøyen skole': ['408'],
#              'Munkegata trikkestopp': ['737'],
#              'St. Hanshaugen park sør': ['432'],
#              'Vippetangen vest': ['452'],
#              'Sjøsiden ved fontenen': ['392'],
#              'Rådhusgata': ['481'],
#              'Vaterlandsparken': ['495'],
#              'Jernbanetorget': ['478'],
#              'Oslo Plaza': ['448'],
#              'Kontraskjæret': ['414'],
#              'Edvard Storms gate': ['476'],
#              'Sjølyst': ['445'],
#              'Hydroparken': ['748'],
#              'Majorstuveien': ['473'],
#              'Arkitekt Rivertz Plass': ['383'],
#              'Helga Helgesens plass': ['480'],
#              'Alexander Kiellands Plass': ['421'],
#              'Bygdøy allé': ['746'],
#              'Slemdalsveien': ['386'],
#              'Colosseum Kino': ['378'],
#              'Uranienborgparken': ['417'],
#              'Briskeby': ['427'],
#              'Frogner Tennisklubb': ['395'],
#              'Norsk Folkemuseum': ['418'],
#              'Majorstuen': ['413'],
#              'Det Teologiske fakultet': ['486'],
#              'Marienlyst': ['471'],
#              'Fredensborg': ['597'],
#              'St. Hanshaugen': ['422'],
#              'Hammersborg Torg': ['739'],
#              'Stensgata': ['382'],
#              'Kirkeristen': ['396'],
#              'Oslo Hospital': ['735'],
#              'Sentrum Scene': ['437'],
#              'Bislett Stadion': ['446'],
#              'Birkelunden': ['424'],
#              'Sofienbergparken sør': ['455'],
#              'Trondheimsveien': ['457'],
#              'Tøyenparken': ['377'],
#              'Lodalen busstopp': ['738'],
#              'Botanisk Hage sør': ['460'],
#              'Nylandsveien': ['734'],
#              'Hallénparken': ['744'],
#              'Sommerfrydhagen': ['485']})
